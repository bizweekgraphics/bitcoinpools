# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
rawBlocksWeekly = pd.read_csv('weeklyBlockSolves.csv', parse_dates=['Date'])
rawBlocksDaily = pd.read_csv('dailyBlockSolves.csv', parse_dates=['Date'])

# Todo: interpolate weekly and daily ("adaptive resampling")
blocksFrame = rawBlocksWeekly.drop('Unnamed: 0', 1).rename(columns=
                                                           {'Date': 'date', 
                                                            'Pool': 'pool', 
                                                            'Number of Blocks': 'blocks', 
                                                            'Percentage of Blocks': 'percentage'})

# %%
import urllib2

# Fetching historical prices from Coindesk. API docs at http://www.coindesk.com/api/
url = 'http://api.coindesk.com/v1/bpi/historical/close.json?start=2011-02-27&end=2014-06-25'
response = urllib2.urlopen(url)
pricesJSON = response.read()
prices = json.loads(pricesJSON)['bpi']

datesAndPrices = []
for x,y in prices.iteritems():
    datesAndPrices.append({'date': x, 'price': y})
    
datesAndPrices = sorted(datesAndPrices, key=lambda datesAndPrices: datesAndPrices['date'])

# %%
# Nest raw blocks 
pools = blocksFrame.groupby('pool').groups.keys()
dates = blocksFrame.groupby('date').groups.keys()

# Get aggregate statistics
poolMax = blocksFrame.groupby('pool').max()[['percentage']].rename(columns={'percentage':'maxPercentage'})
poolSum = blocksFrame.groupby('pool').sum()[['blocks']].rename(columns={'blocks':'sumBlocks'})
poolStats = poolMax.join(poolSum)

# Build an array of dictionaries fit for our eventual charting purposes
blocksByPool = []
for name, stats in poolStats.transpose().to_dict().iteritems():
    values = []
    
    for date in dates:
        
        # numpy date objects will be written to json as %Y-%m-%d
        dateString = pd.to_datetime(str(date)).strftime('%Y-%m-%d')
        
        results = blocksFrame[(blocksFrame['pool'] == name) & (blocksFrame['date'] == date)]
        if len(results) == 0:
            values.append(
                {'date': dateString, 
                 'percentage': 0, 
                 'blocks': 0, 
                 'price': 0,
                 'reward': 0,
                 'revenue': 0,
                 'periodDays': 7 })
        else:
            
            # Cf. https://bitcoinfoundation.org/2012/11/28/happy-halving-day/
            # Since this is just working off weekly data, revenue estimates for that week may be off!!!
            halvingday = np.datetime64('2012-11-28 15:24:38Z')
            reward = 50 if dates[9] < halvingday else 25
            
            # Fetch Bitcoin Coindesk Price Index (BPI) for date. Cf. www.coindesk.com/api/
            price = prices[dateString]
            
            values.append(
                {'date': dateString, 
                 'percentage': results[['percentage']].values[0][0]/100, 
                 'blocks': results[['blocks']].values[0][0],
                 'price': price,
                 'reward': reward,
                 'revenue': results[['blocks']].values[0][0] * price * reward,
                 'periodDays': 7 })
    
    blocksByPool.append(
        {'name': name, 
         'maxPercentage': stats['maxPercentage']/100, 
         'sumBlocks': stats['sumBlocks'],
         'values': values})

blocksByPool
# Out:
# [{'maxPercentage': 0.220735785953177,
#   'name': '50BTC.com',
#   'sumBlocks': 11995.0,
#   'values': [{'blocks': 0,
#     'date': '2011-02-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 167,
#     'date': '2012-09-30',
#     'percentage': 0.15506035283194097,
#     'periodDays': 7,
#     'price': 12.4,
#     'revenue': 51770.000000000007,
#     'reward': 25},
#    {'blocks': 219,
#     'date': '2013-07-28',
#     'percentage': 0.18961038961038998,
#     'periodDays': 7,
#     'price': 92.1,
#     'revenue': 504247.49999999994,
#     'reward': 25},
#    {'blocks': 152,
#     'date': '2013-04-21',
#     'percentage': 0.13780598368086999,
#     'periodDays': 7,
#     'price': 119.2,
#     'revenue': 452960.00000000006,
#     'reward': 25},
#    {'blocks': 170,
#     'date': '2013-01-13',
#     'percentage': 0.17671517671517697,
#     'periodDays': 7,
#     'price': 14.116,
#     'revenue': 59992.999999999993,
#     'reward': 25},
#    {'blocks': 165,
#     'date': '2012-10-07',
#     'percentage': 0.16649848637739698,
#     'periodDays': 7,
#     'price': 11.8,
#     'revenue': 48675.000000000007,
#     'reward': 25},
#    {'blocks': 1,
#     'date': '2014-02-09',
#     'percentage': 0.00081566068515497589,
#     'periodDays': 7,
#     'price': 681.9371,
#     'revenue': 17048.427499999998,
#     'reward': 25},
#    {'blocks': 75,
#     'date': '2012-07-01',
#     'percentage': 0.074110671936758896,
#     'periodDays': 7,
#     'price': 6.629,
#     'revenue': 12429.374999999998,
#     'reward': 25},
#    {'blocks': 17,
#     'date': '2012-03-25',
#     'percentage': 0.015610651974288299,
#     'periodDays': 7,
#     'price': 4.55,
#     'revenue': 1933.7499999999998,
#     'reward': 25},
#    {'blocks': 5,
#     'date': '2012-01-29',
#     'percentage': 0.0049164208456243894,
#     'periodDays': 7,
#     'price': 5.3809,
#     'revenue': 672.61249999999995,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-12-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 8,
#     'date': '2014-04-13',
#     'percentage': 0.0073937153419593301,
#     'periodDays': 7,
#     'price': 414.9495,
#     'revenue': 82989.899999999994,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-09-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 124,
#     'date': '2013-09-29',
#     'percentage': 0.09198813056379819,
#     'periodDays': 7,
#     'price': 125.1807,
#     'revenue': 388060.17000000004,
#     'reward': 25},
#    {'blocks': 214,
#     'date': '2013-06-23',
#     'percentage': 0.19384057971014498,
#     'periodDays': 7,
#     'price': 107.9,
#     'revenue': 577265.0,
#     'reward': 25},
#    {'blocks': 151,
#     'date': '2013-03-17',
#     'percentage': 0.12961373390557898,
#     'periodDays': 7,
#     'price': 47.4,
#     'revenue': 178935.0,
#     'reward': 25},
#    {'blocks': 181,
#     'date': '2012-12-09',
#     'percentage': 0.19504310344827602,
#     'periodDays': 7,
#     'price': 13.388,
#     'revenue': 60580.700000000004,
#     'reward': 25},
#    {'blocks': 152,
#     'date': '2012-09-02',
#     'percentage': 0.138433515482696,
#     'periodDays': 7,
#     'price': 10.2041,
#     'revenue': 38775.580000000002,
#     'reward': 25},
#    {'blocks': 30,
#     'date': '2012-05-27',
#     'percentage': 0.033444816053511697,
#     'periodDays': 7,
#     'price': 5.139,
#     'revenue': 3854.2500000000005,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2012-02-19',
#     'percentage': 0.014591439688716002,
#     'periodDays': 7,
#     'price': 4.3867,
#     'revenue': 1645.0125,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2014-06-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2014-03-09',
#     'percentage': 0.00090909090909090898,
#     'periodDays': 7,
#     'price': 633.1825,
#     'revenue': 15829.5625,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-08-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 197,
#     'date': '2013-08-25',
#     'percentage': 0.14571005917159799,
#     'periodDays': 7,
#     'price': 111.795,
#     'revenue': 550590.375,
#     'reward': 25},
#    {'blocks': 172,
#     'date': '2013-05-19',
#     'percentage': 0.15707762557077598,
#     'periodDays': 7,
#     'price': 122.5,
#     'revenue': 526750.0,
#     'reward': 25},
#    {'blocks': 197,
#     'date': '2013-02-10',
#     'percentage': 0.177317731773177,
#     'periodDays': 7,
#     'price': 23.9698,
#     'revenue': 118051.26499999998,
#     'reward': 25},
#    {'blocks': 184,
#     'date': '2012-11-04',
#     'percentage': 0.17743490838958501,
#     'periodDays': 7,
#     'price': 10.8001,
#     'revenue': 49680.460000000006,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-12-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 74,
#     'date': '2012-07-29',
#     'percentage': 0.066248880931065401,
#     'periodDays': 7,
#     'price': 8.7103,
#     'revenue': 16114.054999999998,
#     'reward': 25},
#    {'blocks': 19,
#     'date': '2012-04-22',
#     'percentage': 0.0192502532928065,
#     'periodDays': 7,
#     'price': 5.2035,
#     'revenue': 2471.6624999999999,
#     'reward': 25},
#    {'blocks': 2,
#     'date': '2012-01-15',
#     'percentage': 0.0018761726078799197,
#     'periodDays': 7,
#     'price': 7.0018,
#     'revenue': 350.09000000000003,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2014-05-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-02-02',
#     'percentage': 0.0016934801016088099,
#     'periodDays': 7,
#     'price': 854.375,
#     'revenue': 42718.75,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-07-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 15,
#     'date': '2013-10-27',
#     'percentage': 0.0099469496021220086,
#     'periodDays': 7,
#     'price': 185.6888,
#     'revenue': 69633.300000000003,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-03-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 244,
#     'date': '2013-07-21',
#     'percentage': 0.20299500831946801,
#     'periodDays': 7,
#     'price': 85.4725,
#     'revenue': 521382.25,
#     'reward': 25},
#    {'blocks': 155,
#     'date': '2013-04-14',
#     'percentage': 0.13069139966273199,
#     'periodDays': 7,
#     'price': 90,
#     'revenue': 348750,
#     'reward': 25},
#    {'blocks': 208,
#     'date': '2013-01-06',
#     'percentage': 0.18995433789954302,
#     'periodDays': 7,
#     'price': 13.454,
#     'revenue': 69960.800000000003,
#     'reward': 25},
#    {'blocks': 73,
#     'date': '2012-06-24',
#     'percentage': 0.068288119738073,
#     'periodDays': 7,
#     'price': 6.35,
#     'revenue': 11588.749999999998,
#     'reward': 25},
#    {'blocks': 4,
#     'date': '2014-04-06',
#     'percentage': 0.0031796502384737703,
#     'periodDays': 7,
#     'price': 460.7028,
#     'revenue': 46070.279999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-09-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 103,
#     'date': '2013-09-22',
#     'percentage': 0.081875993640699501,
#     'periodDays': 7,
#     'price': 122.651,
#     'revenue': 315826.32500000001,
#     'reward': 25},
#    {'blocks': 240,
#     'date': '2013-06-16',
#     'percentage': 0.19123505976095603,
#     'periodDays': 7,
#     'price': 99.9,
#     'revenue': 599400.0,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-10-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 153,
#     'date': '2013-03-10',
#     'percentage': 0.13624220837043599,
#     'periodDays': 7,
#     'price': 46,
#     'revenue': 175950,
#     'reward': 25},
#    {'blocks': 214,
#     'date': '2012-12-02',
#     'percentage': 0.19796484736355199,
#     'periodDays': 7,
#     'price': 12.5,
#     'revenue': 66875.0,
#     'reward': 25},
#    {'blocks': 139,
#     'date': '2012-08-26',
#     'percentage': 0.122359154929577,
#     'periodDays': 7,
#     'price': 10.61,
#     'revenue': 36869.75,
#     'reward': 25},
#    {'blocks': 26,
#     'date': '2012-05-20',
#     'percentage': 0.027659574468085101,
#     'periodDays': 7,
#     'price': 5.09,
#     'revenue': 3308.5,
#     'reward': 25},
#    {'blocks': 11,
#     'date': '2012-02-12',
#     'percentage': 0.0109670987038883,
#     'periodDays': 7,
#     'price': 5.5147,
#     'revenue': 1516.5425,
#     'reward': 25},
#    {'blocks': 2,
#     'date': '2014-06-08',
#     'percentage': 0.0017050298380221699,
#     'periodDays': 7,
#     'price': 653.6402,
#     'revenue': 32682.010000000002,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-11-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-03-02',
#     'percentage': 0.0016433853738701699,
#     'periodDays': 7,
#     'price': 560.3045,
#     'revenue': 28015.224999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-07-31',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2013-11-24',
#     'percentage': 0.00086281276962899098,
#     'periodDays': 7,
#     'price': 751.377,
#     'revenue': 18784.424999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-04-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 224,
#     'date': '2013-08-18',
#     'percentage': 0.170861937452326,
#     'periodDays': 7,
#     'price': 98.845,
#     'revenue': 553532.0,
#     'reward': 25},
#    {'blocks': 197,
#     'date': '2013-05-12',
#     'percentage': 0.16666666666666699,
#     'periodDays': 7,
#     'price': 114.82,
#     'revenue': 565488.49999999988,
#     'reward': 25},
#    {'blocks': 202,
#     'date': '2013-02-03',
#     'percentage': 0.18330308529945602,
#     'periodDays': 7,
#     'price': 20.59,
#     'revenue': 103979.5,
#     'reward': 25},
#    {'blocks': 169,
#     'date': '2012-10-28',
#     'percentage': 0.15462031107044802,
#     'periodDays': 7,
#     'price': 10.7,
#     'revenue': 45207.5,
#     'reward': 25},
#    {'blocks': 57,
#     'date': '2012-07-22',
#     'percentage': 0.054755043227665695,
#     'periodDays': 7,
#     'price': 8.4096,
#     'revenue': 11983.68,
#     'reward': 25},
#    {'blocks': 16,
#     'date': '2012-04-15',
#     'percentage': 0.016443987667009198,
#     'periodDays': 7,
#     'price': 4.9689,
#     'revenue': 1987.5599999999999,
#     'reward': 25},
#    {'blocks': 2,
#     'date': '2012-01-08',
#     'percentage': 0.0017953321364452398,
#     'periodDays': 7,
#     'price': 7.1136,
#     'revenue': 355.68000000000001,
#     'reward': 25},
#    {'blocks': 4,
#     'date': '2014-05-04',
#     'percentage': 0.0035842293906810001,
#     'periodDays': 7,
#     'price': 434.0643,
#     'revenue': 43406.43,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-10-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-01-26',
#     'percentage': 0.0015961691939345602,
#     'periodDays': 7,
#     'price': 880.1523,
#     'revenue': 44007.614999999998,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-06-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 76,
#     'date': '2013-10-20',
#     'percentage': 0.049901510177281699,
#     'periodDays': 7,
#     'price': 163.0632,
#     'revenue': 309820.08000000002,
#     'reward': 25},
#    {'blocks': 225,
#     'date': '2013-07-14',
#     'percentage': 0.18101367658889803,
#     'periodDays': 7,
#     'price': 90.3713,
#     'revenue': 508338.5625,
#     'reward': 25},
#    {'blocks': 111,
#     'date': '2013-04-07',
#     'percentage': 0.09265442404006681,
#     'periodDays': 7,
#     'price': 162.301,
#     'revenue': 450385.27500000002,
#     'reward': 25},
#    {'blocks': 192,
#     'date': '2012-12-30',
#     'percentage': 0.191808191808192,
#     'periodDays': 7,
#     'price': 13.45,
#     'revenue': 64559.999999999993,
#     'reward': 25},
#    {'blocks': 158,
#     'date': '2012-09-23',
#     'percentage': 0.141704035874439,
#     'periodDays': 7,
#     'price': 12.1933,
#     'revenue': 48163.535000000003,
#     'reward': 25},
#    {'blocks': 67,
#     'date': '2012-06-17',
#     'percentage': 0.061865189289011996,
#     'periodDays': 7,
#     'price': 6.1638,
#     'revenue': 10324.365,
#     'reward': 25},
#    {'blocks': 21,
#     'date': '2012-03-11',
#     'percentage': 0.019774011299434999,
#     'periodDays': 7,
#     'price': 4.91,
#     'revenue': 2577.75,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-12-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 5,
#     'date': '2014-03-30',
#     'percentage': 0.0040322580645161298,
#     'periodDays': 7,
#     'price': 461.8695,
#     'revenue': 57733.6875,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-08-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 122,
#     'date': '2013-09-15',
#     'percentage': 0.088023088023088003,
#     'periodDays': 7,
#     'price': 124.5783,
#     'revenue': 379963.815,
#     'reward': 25},
#    {'blocks': 245,
#     'date': '2013-06-09',
#     'percentage': 0.18393393393393395,
#     'periodDays': 7,
#     'price': 100.4374,
#     'revenue': 615179.07499999995,
#     'reward': 25},
#    {'blocks': 173,
#     'date': '2013-03-03',
#     'percentage': 0.146114864864865,
#     'periodDays': 7,
#     'price': 34.5,
#     'revenue': 149212.5,
#     'reward': 25},
#    {'blocks': 195,
#     'date': '2012-11-25',
#     'percentage': 0.185891325071497,
#     'periodDays': 7,
#     'price': 12.4821,
#     'revenue': 60850.237500000003,
#     'reward': 25},
#    {'blocks': 86,
#     'date': '2012-08-19',
#     'percentage': 0.079189686924493602,
#     'periodDays': 7,
#     'price': 8,
#     'revenue': 17200,
#     'reward': 25},
#    {'blocks': 24,
#     'date': '2012-05-13',
#     'percentage': 0.022304832713754597,
#     'periodDays': 7,
#     'price': 4.93,
#     'revenue': 2958.0,
#     'reward': 25},
#    {'blocks': 11,
#     'date': '2012-02-05',
#     'percentage': 0.0099637681159420299,
#     'periodDays': 7,
#     'price': 5.6888,
#     'revenue': 1564.4200000000001,
#     'reward': 25},
#    {'blocks': 79,
#     'date': '2012-08-12',
#     'percentage': 0.071622846781505003,
#     'periodDays': 7,
#     'price': 11.624,
#     'revenue': 22957.400000000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2014-06-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 3,
#     'date': '2014-02-23',
#     'percentage': 0.0024549918166939396,
#     'periodDays': 7,
#     'price': 604.5823,
#     'revenue': 45343.672500000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-07-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2013-11-17',
#     'percentage': 0.0015748031496063001,
#     'periodDays': 7,
#     'price': 476.295,
#     'revenue': 23814.75,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-04-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 220,
#     'date': '2013-08-11',
#     'percentage': 0.16248153618906902,
#     'periodDays': 7,
#     'price': 94.1625,
#     'revenue': 517893.75,
#     'reward': 25},
#    {'blocks': 164,
#     'date': '2013-05-05',
#     'percentage': 0.151711378353376,
#     'periodDays': 7,
#     'price': 115.98,
#     'revenue': 475518.0,
#     'reward': 25},
#    {'blocks': 188,
#     'date': '2013-01-27',
#     'percentage': 0.19164118246687104,
#     'periodDays': 7,
#     'price': 17.8182,
#     'revenue': 83745.540000000008,
#     'reward': 25},
#    {'blocks': 204,
#     'date': '2012-10-21',
#     'percentage': 0.19558964525407499,
#     'periodDays': 7,
#     'price': 11.6311,
#     'revenue': 59318.610000000001,
#     'reward': 25},
#    {'blocks': 46,
#     'date': '2012-07-15',
#     'percentage': 0.042830540037243903,
#     'periodDays': 7,
#     'price': 7.621,
#     'revenue': 8764.1500000000015,
#     'reward': 25},
#    {'blocks': 13,
#     'date': '2012-04-08',
#     'percentage': 0.014285714285714299,
#     'periodDays': 7,
#     'price': 4.7925,
#     'revenue': 1557.5625000000002,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-01-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-04-27',
#     'percentage': 0.0017182130584192405,
#     'periodDays': 7,
#     'price': 429.6537,
#     'revenue': 21482.685000000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-09-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2014-01-19',
#     'percentage': 0.00081103000811029999,
#     'periodDays': 7,
#     'price': 878.6807,
#     'revenue': 21967.017500000002,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-06-19',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 61,
#     'date': '2013-10-13',
#     'percentage': 0.047955974842767306,
#     'periodDays': 7,
#     'price': 130.4155,
#     'revenue': 198883.63750000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-03-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 195,
#     'date': '2013-07-07',
#     'percentage': 0.16455696202531597,
#     'periodDays': 7,
#     'price': 72.5053,
#     'revenue': 353463.33750000002,
#     'reward': 25},
#    {'blocks': 126,
#     'date': '2013-03-31',
#     'percentage': 0.110043668122271,
#     'periodDays': 7,
#     'price': 93.03,
#     'revenue': 293044.5,
#     'reward': 25},
#    {'blocks': 198,
#     'date': '2012-12-23',
#     'percentage': 0.220735785953177,
#     'periodDays': 7,
#     'price': 13.312,
#     'revenue': 65894.399999999994,
#     'reward': 25},
#    {'blocks': 150,
#     'date': '2012-09-16',
#     'percentage': 0.143540669856459,
#     'periodDays': 7,
#     'price': 11.87,
#     'revenue': 44512.499999999993,
#     'reward': 25},
#    {'blocks': 183,
#     'date': '2012-10-14',
#     'percentage': 0.17784256559766798,
#     'periodDays': 7,
#     'price': 11.7389,
#     'revenue': 53705.467499999999,
#     'reward': 25},
#    {'blocks': 50,
#     'date': '2012-06-10',
#     'percentage': 0.0472143531633617,
#     'periodDays': 7,
#     'price': 5.4683,
#     'revenue': 6835.3750000000009,
#     'reward': 25},
#    {'blocks': 14,
#     'date': '2012-03-04',
#     'percentage': 0.013448607108549499,
#     'periodDays': 7,
#     'price': 4.82,
#     'revenue': 1687.0,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-04-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 6,
#     'date': '2014-03-23',
#     'percentage': 0.0051238257899231402,
#     'periodDays': 7,
#     'price': 561.3534,
#     'revenue': 84203.009999999995,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-08-21',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2013-12-15',
#     'percentage': 0.00079176563737133805,
#     'periodDays': 7,
#     'price': 879.4692,
#     'revenue': 21986.73,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-05-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 153,
#     'date': '2013-09-08',
#     'percentage': 0.11751152073732701,
#     'periodDays': 7,
#     'price': 116.595,
#     'revenue': 445975.875,
#     'reward': 25},
#    {'blocks': 218,
#     'date': '2013-06-02',
#     'percentage': 0.17694805194805202,
#     'periodDays': 7,
#     'price': 122.5,
#     'revenue': 667625.0,
#     'reward': 25},
#    {'blocks': 225,
#     'date': '2013-02-24',
#     'percentage': 0.18579686209744001,
#     'periodDays': 7,
#     'price': 29.89,
#     'revenue': 168131.25,
#     'reward': 25},
#    {'blocks': 168,
#     'date': '2012-11-18',
#     'percentage': 0.17090539165818899,
#     'periodDays': 7,
#     'price': 11.6515,
#     'revenue': 48936.300000000003,
#     'reward': 25},
#    {'blocks': 3,
#     'date': '2014-05-25',
#     'percentage': 0.0025359256128486894,
#     'periodDays': 7,
#     'price': 570.095,
#     'revenue': 42757.125,
#     'reward': 25},
#    {'blocks': 3,
#     'date': '2014-02-16',
#     'percentage': 0.0025167785234899306,
#     'periodDays': 7,
#     'price': 610.6525,
#     'revenue': 45798.9375,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-07-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 239,
#     'date': '2013-08-04',
#     'percentage': 0.187893081761006,
#     'periodDays': 7,
#     'price': 96.6,
#     'revenue': 577185.0,
#     'reward': 25},
#    {'blocks': 194,
#     'date': '2013-04-28',
#     'percentage': 0.16884247171453398,
#     'periodDays': 7,
#     'price': 134.4444,
#     'revenue': 652055.33999999997,
#     'reward': 25},
#    {'blocks': 33,
#     'date': '2012-05-06',
#     'percentage': 0.028374892519346499,
#     'periodDays': 7,
#     'price': 5.0499,
#     'revenue': 4166.1675000000005,
#     'reward': 25},
#    {'blocks': 182,
#     'date': '2013-01-20',
#     'percentage': 0.19612068965517199,
#     'periodDays': 7,
#     'price': 15.7,
#     'revenue': 71435.0,
#     'reward': 25},
#    {'blocks': 40,
#     'date': '2012-07-08',
#     'percentage': 0.037418147801683802,
#     'periodDays': 7,
#     'price': 6.799,
#     'revenue': 6799.0000000000009,
#     'reward': 25},
#    {'blocks': 17,
#     'date': '2012-04-01',
#     'percentage': 0.015755329008341101,
#     'periodDays': 7,
#     'price': 4.827,
#     'revenue': 2051.4749999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-12-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-04-20',
#     'percentage': 0.0016542597187758502,
#     'periodDays': 7,
#     'price': 497.3177,
#     'revenue': 24865.884999999998,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-09-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 104,
#     'date': '2013-10-06',
#     'percentage': 0.079449961802902994,
#     'periodDays': 7,
#     'price': 121.6828,
#     'revenue': 316375.28000000003,
#     'reward': 25},
#    {'blocks': 193,
#     'date': '2013-06-30',
#     'percentage': 0.16768027801911398,
#     'periodDays': 7,
#     'price': 97.51,
#     'revenue': 470485.75,
#     'reward': 25},
#    {'blocks': 160,
#     'date': '2013-03-24',
#     'percentage': 0.110803324099723,
#     'periodDays': 7,
#     'price': 71.5,
#     'revenue': 286000.0,
#     'reward': 25},
#    {'blocks': 172,
#     'date': '2012-12-16',
#     'percentage': 0.191964285714286,
#     'periodDays': 7,
#     'price': 13.3,
#     'revenue': 57190.0,
#     'reward': 25},
#    {'blocks': 183,
#     'date': '2012-09-09',
#     'percentage': 0.16080843585237301,
#     'periodDays': 7,
#     'price': 11.02,
#     'revenue': 50416.5,
#     'reward': 25},
#    {'blocks': 39,
#     'date': '2012-06-03',
#     'percentage': 0.038690476190476206,
#     'periodDays': 7,
#     'price': 5.2051,
#     'revenue': 5074.9724999999999,
#     'reward': 25},
#    {'blocks': 13,
#     'date': '2012-02-26',
#     'percentage': 0.012195121951219499,
#     'periodDays': 7,
#     'price': 4.922,
#     'revenue': 1599.6499999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-11-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 5,
#     'date': '2014-03-16',
#     'percentage': 0.0043936731107205602,
#     'periodDays': 7,
#     'price': 630.7167,
#     'revenue': 78839.587499999994,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-08-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 21,
#     'date': '2012-03-18',
#     'percentage': 0.020172910662824197,
#     'periodDays': 7,
#     'price': 5.2794,
#     'revenue': 2771.6849999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-05-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 157,
#     'date': '2013-09-01',
#     'percentage': 0.12256049960968002,
#     'periodDays': 7,
#     'price': 128.2597,
#     'revenue': 503419.32250000001,
#     'reward': 25},
#    {'blocks': 194,
#     'date': '2013-05-26',
#     'percentage': 0.176363636363636,
#     'periodDays': 7,
#     'price': 133.5,
#     'revenue': 647475.0,
#     'reward': 25},
#    {'blocks': 208,
#     'date': '2013-02-17',
#     'percentage': 0.18102697998259398,
#     'periodDays': 7,
#     'price': 26.8146,
#     'revenue': 139435.91999999998,
#     'reward': 25},
#    {'blocks': 182,
#     'date': '2012-11-11',
#     'percentage': 0.171860245514636,
#     'periodDays': 7,
#     'price': 10.8687,
#     'revenue': 49452.585000000006,
#     'reward': 25},
#    {'blocks': 81,
#     'date': '2012-08-05',
#     'percentage': 0.0743801652892562,
#     'periodDays': 7,
#     'price': 10.87,
#     'revenue': 22011.749999999996,
#     'reward': 25},
#    {'blocks': 22,
#     'date': '2012-04-29',
#     'percentage': 0.022403258655804503,
#     'periodDays': 7,
#     'price': 4.9044,
#     'revenue': 2697.4200000000001,
#     'reward': 25},
#    {'blocks': 6,
#     'date': '2012-01-22',
#     'percentage': 0.0056710775047259,
#     'periodDays': 7,
#     'price': 6.3097,
#     'revenue': 946.45500000000004,
#     'reward': 25},
#    {'blocks': 4,
#     'date': '2014-05-18',
#     'percentage': 0.0034692107545533394,
#     'periodDays': 7,
#     'price': 444.809,
#     'revenue': 44480.900000000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-10-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0}]},
#  {'maxPercentage': 0.125114155251142,
#   'name': 'BitMinter',
#   'sumBlocks': 5763.0,
#   'values': [{'blocks': 0,
#     'date': '2011-02-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2011-07-10',
#     'percentage': 0.00092936802973977702,
#     'periodDays': 7,
#     'price': 14.9,
#     'revenue': 372.5,
#     'reward': 25},
#    {'blocks': 78,
#     'date': '2013-11-03',
#     'percentage': 0.058646616541353398,
#     'periodDays': 7,
#     'price': 207.6335,
#     'revenue': 404885.32500000001,
#     'reward': 25},
#    {'blocks': 70,
#     'date': '2012-09-30',
#     'percentage': 0.064995357474466109,
#     'periodDays': 7,
#     'price': 12.4,
#     'revenue': 21700.0,
#     'reward': 25},
#    {'blocks': 32,
#     'date': '2013-07-28',
#     'percentage': 0.027705627705627695,
#     'periodDays': 7,
#     'price': 92.1,
#     'revenue': 73680.0,
#     'reward': 25},
#    {'blocks': 91,
#     'date': '2013-04-21',
#     'percentage': 0.0825022665457842,
#     'periodDays': 7,
#     'price': 119.2,
#     'revenue': 271180.0,
#     'reward': 25},
#    {'blocks': 61,
#     'date': '2013-01-13',
#     'percentage': 0.063409563409563399,
#     'periodDays': 7,
#     'price': 14.116,
#     'revenue': 21526.900000000001,
#     'reward': 25},
#    {'blocks': 70,
#     'date': '2012-10-07',
#     'percentage': 0.070635721493440995,
#     'periodDays': 7,
#     'price': 11.8,
#     'revenue': 20650.0,
#     'reward': 25},
#    {'blocks': 29,
#     'date': '2014-02-09',
#     'percentage': 0.023654159869494304,
#     'periodDays': 7,
#     'price': 681.9371,
#     'revenue': 494404.39749999996,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2012-07-01',
#     'percentage': 0.014822134387351799,
#     'periodDays': 7,
#     'price': 6.629,
#     'revenue': 2485.8749999999995,
#     'reward': 25},
#    {'blocks': 11,
#     'date': '2012-03-25',
#     'percentage': 0.0101010101010101,
#     'periodDays': 7,
#     'price': 4.55,
#     'revenue': 1251.25,
#     'reward': 25},
#    {'blocks': 10,
#     'date': '2012-01-29',
#     'percentage': 0.0098328416912487702,
#     'periodDays': 7,
#     'price': 5.3809,
#     'revenue': 1345.2249999999999,
#     'reward': 25},
#    {'blocks': 8,
#     'date': '2011-12-18',
#     'percentage': 0.0084745762711864389,
#     'periodDays': 7,
#     'price': 3.193,
#     'revenue': 638.60000000000002,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2014-04-13',
#     'percentage': 0.013863216266173796,
#     'periodDays': 7,
#     'price': 414.9495,
#     'revenue': 155606.0625,
#     'reward': 25},
#    {'blocks': 1,
#     'date': '2011-09-11',
#     'percentage': 0.0010070493454179302,
#     'periodDays': 7,
#     'price': 5.8644,
#     'revenue': 146.60999999999999,
#     'reward': 25},
#    {'blocks': 28,
#     'date': '2014-01-05',
#     'percentage': 0.024013722126929701,
#     'periodDays': 7,
#     'price': 940.0972,
#     'revenue': 658068.04000000004,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-06-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 38,
#     'date': '2013-09-29',
#     'percentage': 0.028189910979228502,
#     'periodDays': 7,
#     'price': 125.1807,
#     'revenue': 118921.66500000001,
#     'reward': 25},
#    {'blocks': 28,
#     'date': '2013-06-23',
#     'percentage': 0.025362318840579701,
#     'periodDays': 7,
#     'price': 107.9,
#     'revenue': 75530.0,
#     'reward': 25},
#    {'blocks': 56,
#     'date': '2013-03-17',
#     'percentage': 0.048068669527896998,
#     'periodDays': 7,
#     'price': 47.4,
#     'revenue': 66360.0,
#     'reward': 25},
#    {'blocks': 82,
#     'date': '2012-12-09',
#     'percentage': 0.08836206896551721,
#     'periodDays': 7,
#     'price': 13.388,
#     'revenue': 27445.400000000001,
#     'reward': 25},
#    {'blocks': 49,
#     'date': '2012-09-02',
#     'percentage': 0.044626593806921695,
#     'periodDays': 7,
#     'price': 10.2041,
#     'revenue': 12500.022499999999,
#     'reward': 25},
#    {'blocks': 12,
#     'date': '2012-05-27',
#     'percentage': 0.013377926421404699,
#     'periodDays': 7,
#     'price': 5.139,
#     'revenue': 1541.7000000000003,
#     'reward': 25},
#    {'blocks': 8,
#     'date': '2012-02-19',
#     'percentage': 0.0077821011673151795,
#     'periodDays': 7,
#     'price': 4.3867,
#     'revenue': 877.34000000000003,
#     'reward': 25},
#    {'blocks': 17,
#     'date': '2014-06-15',
#     'percentage': 0.015205724508050099,
#     'periodDays': 7,
#     'price': 591.9718,
#     'revenue': 251588.01499999998,
#     'reward': 25},
#    {'blocks': 7,
#     'date': '2011-11-13',
#     'percentage': 0.0070778564206269001,
#     'periodDays': 7,
#     'price': 2.9969,
#     'revenue': 524.45749999999998,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2014-03-09',
#     'percentage': 0.013636363636363603,
#     'periodDays': 7,
#     'price': 633.1825,
#     'revenue': 237443.43749999997,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-08-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 59,
#     'date': '2013-12-01',
#     'percentage': 0.049044056525353305,
#     'periodDays': 7,
#     'price': 946.9237,
#     'revenue': 1396712.4575000003,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-05-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 48,
#     'date': '2013-08-25',
#     'percentage': 0.035502958579881699,
#     'periodDays': 7,
#     'price': 111.795,
#     'revenue': 134154.0,
#     'reward': 25},
#    {'blocks': 137,
#     'date': '2013-05-19',
#     'percentage': 0.125114155251142,
#     'periodDays': 7,
#     'price': 122.5,
#     'revenue': 419562.5,
#     'reward': 25},
#    {'blocks': 73,
#     'date': '2013-02-10',
#     'percentage': 0.065706570657065699,
#     'periodDays': 7,
#     'price': 23.9698,
#     'revenue': 43744.885000000002,
#     'reward': 25},
#    {'blocks': 86,
#     'date': '2012-11-04',
#     'percentage': 0.082931533269045302,
#     'periodDays': 7,
#     'price': 10.8001,
#     'revenue': 23220.215,
#     'reward': 25},
#    {'blocks': 3,
#     'date': '2011-12-11',
#     'percentage': 0.00283553875236295,
#     'periodDays': 7,
#     'price': 3.2511,
#     'revenue': 243.83249999999998,
#     'reward': 25},
#    {'blocks': 36,
#     'date': '2012-07-29',
#     'percentage': 0.032229185317815601,
#     'periodDays': 7,
#     'price': 8.7103,
#     'revenue': 7839.2700000000004,
#     'reward': 25},
#    {'blocks': 6,
#     'date': '2012-04-22',
#     'percentage': 0.0060790273556231011,
#     'periodDays': 7,
#     'price': 5.2035,
#     'revenue': 780.52499999999998,
#     'reward': 25},
#    {'blocks': 9,
#     'date': '2012-01-15',
#     'percentage': 0.0084427767354596592,
#     'periodDays': 7,
#     'price': 7.0018,
#     'revenue': 1575.4050000000002,
#     'reward': 25},
#    {'blocks': 17,
#     'date': '2014-05-11',
#     'percentage': 0.014847161572052401,
#     'periodDays': 7,
#     'price': 436.542,
#     'revenue': 185530.35000000001,
#     'reward': 25},
#    {'blocks': 5,
#     'date': '2011-10-09',
#     'percentage': 0.0055066079295154205,
#     'periodDays': 7,
#     'price': 4.1029,
#     'revenue': 512.86249999999995,
#     'reward': 25},
#    {'blocks': 22,
#     'date': '2014-02-02',
#     'percentage': 0.018628281117696897,
#     'periodDays': 7,
#     'price': 854.375,
#     'revenue': 469906.25,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-07-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 81,
#     'date': '2013-10-27',
#     'percentage': 0.053713527851458893,
#     'periodDays': 7,
#     'price': 185.6888,
#     'revenue': 376019.82000000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-03-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 34,
#     'date': '2013-07-21',
#     'percentage': 0.028286189683860197,
#     'periodDays': 7,
#     'price': 85.4725,
#     'revenue': 72651.625,
#     'reward': 25},
#    {'blocks': 94,
#     'date': '2013-04-14',
#     'percentage': 0.079258010118043801,
#     'periodDays': 7,
#     'price': 90,
#     'revenue': 211500,
#     'reward': 25},
#    {'blocks': 50,
#     'date': '2013-01-06',
#     'percentage': 0.045662100456620995,
#     'periodDays': 7,
#     'price': 13.454,
#     'revenue': 16817.5,
#     'reward': 25},
#    {'blocks': 20,
#     'date': '2012-06-24',
#     'percentage': 0.018709073900841901,
#     'periodDays': 7,
#     'price': 6.35,
#     'revenue': 3175.0,
#     'reward': 25},
#    {'blocks': 9,
#     'date': '2014-04-06',
#     'percentage': 0.0071542130365659807,
#     'periodDays': 7,
#     'price': 460.7028,
#     'revenue': 103658.13,
#     'reward': 25},
#    {'blocks': 5,
#     'date': '2011-09-04',
#     'percentage': 0.0050761421319796994,
#     'periodDays': 7,
#     'price': 8.178,
#     'revenue': 1022.25,
#     'reward': 25},
#    {'blocks': 63,
#     'date': '2013-12-29',
#     'percentage': 0.053164556962025308,
#     'periodDays': 7,
#     'price': 745.0712,
#     'revenue': 1173487.1399999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-05-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 33,
#     'date': '2013-09-22',
#     'percentage': 0.026232114467408599,
#     'periodDays': 7,
#     'price': 122.651,
#     'revenue': 101187.075,
#     'reward': 25},
#    {'blocks': 74,
#     'date': '2013-06-16',
#     'percentage': 0.058964143426294802,
#     'periodDays': 7,
#     'price': 99.9,
#     'revenue': 184815.0,
#     'reward': 25},
#    {'blocks': 12,
#     'date': '2011-10-23',
#     'percentage': 0.014563106796116498,
#     'periodDays': 7,
#     'price': 3.17,
#     'revenue': 951.0,
#     'reward': 25},
#    {'blocks': 34,
#     'date': '2013-03-10',
#     'percentage': 0.030276046304541403,
#     'periodDays': 7,
#     'price': 46,
#     'revenue': 39100,
#     'reward': 25},
#    {'blocks': 89,
#     'date': '2012-12-02',
#     'percentage': 0.082331174838112892,
#     'periodDays': 7,
#     'price': 12.5,
#     'revenue': 27812.5,
#     'reward': 25},
#    {'blocks': 41,
#     'date': '2012-08-26',
#     'percentage': 0.0360915492957746,
#     'periodDays': 7,
#     'price': 10.61,
#     'revenue': 10875.25,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2012-05-20',
#     'percentage': 0.015957446808510602,
#     'periodDays': 7,
#     'price': 5.09,
#     'revenue': 1908.7499999999998,
#     'reward': 25},
#    {'blocks': 8,
#     'date': '2012-02-12',
#     'percentage': 0.0079760717846460594,
#     'periodDays': 7,
#     'price': 5.5147,
#     'revenue': 1102.9400000000001,
#     'reward': 25},
#    {'blocks': 16,
#     'date': '2014-06-08',
#     'percentage': 0.013640238704177299,
#     'periodDays': 7,
#     'price': 653.6402,
#     'revenue': 261456.08000000002,
#     'reward': 25},
#    {'blocks': 5,
#     'date': '2011-11-06',
#     'percentage': 0.0051867219917012394,
#     'periodDays': 7,
#     'price': 2.9596,
#     'revenue': 369.94999999999999,
#     'reward': 25},
#    {'blocks': 21,
#     'date': '2014-03-02',
#     'percentage': 0.0172555464256368,
#     'periodDays': 7,
#     'price': 560.3045,
#     'revenue': 294159.86249999999,
#     'reward': 25},
#    {'blocks': 1,
#     'date': '2011-07-31',
#     'percentage': 0.00086805555555555594,
#     'periodDays': 7,
#     'price': 13.35,
#     'revenue': 333.75,
#     'reward': 25},
#    {'blocks': 68,
#     'date': '2013-11-24',
#     'percentage': 0.058671268334771397,
#     'periodDays': 7,
#     'price': 751.377,
#     'revenue': 1277340.8999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-04-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 44,
#     'date': '2013-08-18',
#     'percentage': 0.033562166285278396,
#     'periodDays': 7,
#     'price': 98.845,
#     'revenue': 108729.5,
#     'reward': 25},
#    {'blocks': 143,
#     'date': '2013-05-12',
#     'percentage': 0.12098138747884901,
#     'periodDays': 7,
#     'price': 114.82,
#     'revenue': 410481.49999999994,
#     'reward': 25},
#    {'blocks': 68,
#     'date': '2013-02-03',
#     'percentage': 0.061705989110707807,
#     'periodDays': 7,
#     'price': 20.59,
#     'revenue': 35003.0,
#     'reward': 25},
#    {'blocks': 92,
#     'date': '2012-10-28',
#     'percentage': 0.084172003659652314,
#     'periodDays': 7,
#     'price': 10.7,
#     'revenue': 24610.0,
#     'reward': 25},
#    {'blocks': 25,
#     'date': '2012-07-22',
#     'percentage': 0.024015369836695499,
#     'periodDays': 7,
#     'price': 8.4096,
#     'revenue': 5255.9999999999991,
#     'reward': 25},
#    {'blocks': 8,
#     'date': '2012-04-15',
#     'percentage': 0.0082219938335046198,
#     'periodDays': 7,
#     'price': 4.9689,
#     'revenue': 993.77999999999997,
#     'reward': 25},
#    {'blocks': 14,
#     'date': '2012-01-08',
#     'percentage': 0.012567324955116699,
#     'periodDays': 7,
#     'price': 7.1136,
#     'revenue': 2489.7600000000002,
#     'reward': 25},
#    {'blocks': 21,
#     'date': '2014-05-04',
#     'percentage': 0.018817204301075301,
#     'periodDays': 7,
#     'price': 434.0643,
#     'revenue': 227883.75750000001,
#     'reward': 25},
#    {'blocks': 1,
#     'date': '2011-10-02',
#     'percentage': 0.0010626992561105198,
#     'periodDays': 7,
#     'price': 5.027,
#     'revenue': 125.675,
#     'reward': 25},
#    {'blocks': 21,
#     'date': '2014-01-26',
#     'percentage': 0.0167597765363128,
#     'periodDays': 7,
#     'price': 880.1523,
#     'revenue': 462079.95750000002,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-06-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 85,
#     'date': '2013-10-20',
#     'percentage': 0.0558108995403808,
#     'periodDays': 7,
#     'price': 163.0632,
#     'revenue': 346509.29999999999,
#     'reward': 25},
#    {'blocks': 38,
#     'date': '2013-07-14',
#     'percentage': 0.030571198712791604,
#     'periodDays': 7,
#     'price': 90.3713,
#     'revenue': 85852.735000000001,
#     'reward': 25},
#    {'blocks': 59,
#     'date': '2013-04-07',
#     'percentage': 0.049248747913188604,
#     'periodDays': 7,
#     'price': 162.301,
#     'revenue': 239393.97500000001,
#     'reward': 25},
#    {'blocks': 54,
#     'date': '2012-12-30',
#     'percentage': 0.053946053946053896,
#     'periodDays': 7,
#     'price': 13.45,
#     'revenue': 18157.5,
#     'reward': 25},
#    {'blocks': 67,
#     'date': '2012-09-23',
#     'percentage': 0.060089686098654699,
#     'periodDays': 7,
#     'price': 12.1933,
#     'revenue': 20423.7775,
#     'reward': 25},
#    {'blocks': 20,
#     'date': '2012-06-17',
#     'percentage': 0.018467220683287201,
#     'periodDays': 7,
#     'price': 6.1638,
#     'revenue': 3081.9000000000001,
#     'reward': 25},
#    {'blocks': 4,
#     'date': '2012-03-11',
#     'percentage': 0.003766478342749529,
#     'periodDays': 7,
#     'price': 4.91,
#     'revenue': 491.0,
#     'reward': 25},
#    {'blocks': 5,
#     'date': '2011-12-04',
#     'percentage': 0.0048971596474045101,
#     'periodDays': 7,
#     'price': 2.8281,
#     'revenue': 353.51249999999999,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2014-03-30',
#     'percentage': 0.012096774193548401,
#     'periodDays': 7,
#     'price': 461.8695,
#     'revenue': 173201.0625,
#     'reward': 25},
#    {'blocks': 4,
#     'date': '2011-08-28',
#     'percentage': 0.0039138943248532305,
#     'periodDays': 7,
#     'price': 9.0701,
#     'revenue': 907.00999999999999,
#     'reward': 25},
#    {'blocks': 62,
#     'date': '2013-12-22',
#     'percentage': 0.046096654275092901,
#     'periodDays': 7,
#     'price': 617.8158,
#     'revenue': 957614.48999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-05-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 32,
#     'date': '2013-09-15',
#     'percentage': 0.023088023088023098,
#     'periodDays': 7,
#     'price': 124.5783,
#     'revenue': 99662.639999999999,
#     'reward': 25},
#    {'blocks': 78,
#     'date': '2013-06-09',
#     'percentage': 0.058558558558558606,
#     'periodDays': 7,
#     'price': 100.4374,
#     'revenue': 195852.92999999999,
#     'reward': 25},
#    {'blocks': 50,
#     'date': '2013-03-03',
#     'percentage': 0.042229729729729701,
#     'periodDays': 7,
#     'price': 34.5,
#     'revenue': 43125.0,
#     'reward': 25},
#    {'blocks': 64,
#     'date': '2012-11-25',
#     'percentage': 0.061010486177311696,
#     'periodDays': 7,
#     'price': 12.4821,
#     'revenue': 19971.360000000001,
#     'reward': 25},
#    {'blocks': 63,
#     'date': '2012-08-19',
#     'percentage': 0.058011049723756904,
#     'periodDays': 7,
#     'price': 8,
#     'revenue': 12600,
#     'reward': 25},
#    {'blocks': 14,
#     'date': '2012-05-13',
#     'percentage': 0.013011152416356898,
#     'periodDays': 7,
#     'price': 4.93,
#     'revenue': 1725.5,
#     'reward': 25},
#    {'blocks': 10,
#     'date': '2012-02-05',
#     'percentage': 0.0090579710144927505,
#     'periodDays': 7,
#     'price': 5.6888,
#     'revenue': 1422.2,
#     'reward': 25},
#    {'blocks': 45,
#     'date': '2012-08-12',
#     'percentage': 0.040797824116047099,
#     'periodDays': 7,
#     'price': 11.624,
#     'revenue': 13077.000000000002,
#     'reward': 25},
#    {'blocks': 17,
#     'date': '2014-06-01',
#     'percentage': 0.015755329008341101,
#     'periodDays': 7,
#     'price': 629.0242,
#     'revenue': 267335.28499999997,
#     'reward': 25},
#    {'blocks': 6,
#     'date': '2011-10-30',
#     'percentage': 0.0075093867334167707,
#     'periodDays': 7,
#     'price': 3.27,
#     'revenue': 490.5,
#     'reward': 25},
#    {'blocks': 15,
#     'date': '2014-02-23',
#     'percentage': 0.012274959083469698,
#     'periodDays': 7,
#     'price': 604.5823,
#     'revenue': 226718.36250000002,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-07-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 79,
#     'date': '2013-11-17',
#     'percentage': 0.062204724409448804,
#     'periodDays': 7,
#     'price': 476.295,
#     'revenue': 940682.625,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2011-04-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 57,
#     'date': '2013-08-11',
#     'percentage': 0.042097488921713395,
#     'periodDays': 7,
#     'price': 94.1625,
#     'revenue': 134181.5625,
#     'reward': 25},
#    {'blocks': 69,
#     'date': '2013-05-05',
#     'percentage': 0.06382978723404259,
#     'periodDays': 7,
#     'price': 115.98,
#     'revenue': 200065.5,
#     'reward': 25},
#    {'blocks': 65,
#     'date': '2013-01-27',
#     'percentage': 0.066258919469928595,
#     'periodDays': 7,
#     'price': 17.8182,
#     'revenue': 28954.575000000001,
#     'reward': 25},
#    {'blocks': 92,
#     'date': '2012-10-21',
#     'percentage': 0.0882070949185043,
#     'periodDays': 7,
#     'price': 11.6311,
#     'revenue': 26751.530000000002,
#     'reward': 25},
#    {'blocks': 41,
#     'date': '2012-07-15',
#     'percentage': 0.038175046554934797,
#     'periodDays': 7,
#     'price': 7.621,
#     'revenue': 7811.5250000000005,
#     'reward': 25},
#    {'blocks': 13,
#     'date': '2012-04-08',
#     'percentage': 0.014285714285714299,
#     'periodDays': 7,
#     'price': 4.7925,
#     'revenue': 1557.5625000000002,
#     'reward': 25},
#    {'blocks': 9,
#     'date': '2012-01-01',
#     'percentage': 0.0083179297597042508,
#     'periodDays': 7,
#     'price': 5.2677,
#     'revenue': 1185.2324999999998,
#     'reward': 25},
#    {'blocks': 19,
#     'date': '2014-04-27',
#     'percentage': 0.016323024054982802,
#     'periodDays': 7,
#     'price': 429.6537,
#     'revenue': 204085.50750000001,
#     'reward': 25},
#    {'blocks': 1,
#     'date': '2011-09-25',
#     'percentage': 0.0010193679918450598,
#     'periodDays': 7,
#     'price': 5.33,
#     'revenue': 133.25,
#     'reward': 25},
#    {'blocks': 33,
#     'date': '2014-01-19',
#     'percentage': 0.026763990267639901,
#     'periodDays': 7,
# ...
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-02-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-06-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-31',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-08-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-05-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-02-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-10-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 18,
#     'date': '2012-07-22',
#     'percentage': 0.017291066282420803,
#     'periodDays': 7,
#     'price': 8.4096,
#     'revenue': 3784.3199999999997,
#     'reward': 25},
#    {'blocks': 13,
#     'date': '2012-04-15',
#     'percentage': 0.013360739979445001,
#     'periodDays': 7,
#     'price': 4.9689,
#     'revenue': 1614.8924999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-01-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-05-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-10-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-07-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-04-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-12-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-09-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 17,
#     'date': '2012-06-17',
#     'percentage': 0.015697137580794097,
#     'periodDays': 7,
#     'price': 6.1638,
#     'revenue': 2619.6149999999998,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-03-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-12-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-09-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-06-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-03-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-11-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 12,
#     'date': '2012-08-19',
#     'percentage': 0.011049723756906099,
#     'periodDays': 7,
#     'price': 8,
#     'revenue': 2400,
#     'reward': 25},
#    {'blocks': 35,
#     'date': '2012-05-13',
#     'percentage': 0.032527881040892201,
#     'periodDays': 7,
#     'price': 4.93,
#     'revenue': 4313.75,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-02-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 16,
#     'date': '2012-08-12',
#     'percentage': 0.014505893019039,
#     'periodDays': 7,
#     'price': 11.624,
#     'revenue': 4649.6000000000004,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2014-06-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-02-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-08-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-05-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-01-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-10-21',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 18,
#     'date': '2012-07-15',
#     'percentage': 0.0167597765363128,
#     'periodDays': 7,
#     'price': 7.621,
#     'revenue': 3429.4499999999998,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-04-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-01-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-04-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-09-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-19',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-19',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-10-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-07-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-03-31',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-12-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-09-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-10-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 22,
#     'date': '2012-06-10',
#     'percentage': 0.0207743153918791,
#     'periodDays': 7,
#     'price': 5.4683,
#     'revenue': 3007.5650000000001,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-03-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-21',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-09-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-06-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-02-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-11-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-05-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-02-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-08-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-04-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 18,
#     'date': '2012-05-06',
#     'percentage': 0.0154772141014617,
#     'periodDays': 7,
#     'price': 5.0499,
#     'revenue': 2272.4549999999999,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2013-01-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 13,
#     'date': '2012-07-08',
#     'percentage': 0.0121608980355472,
#     'periodDays': 7,
#     'price': 6.799,
#     'revenue': 2209.6750000000002,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-04-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-12-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-04-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-09-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-10-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-06-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-03-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-12-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-09-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 51,
#     'date': '2012-06-03',
#     'percentage': 0.050595238095238096,
#     'periodDays': 7,
#     'price': 5.2051,
#     'revenue': 6636.5025000000005,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-02-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-03-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-09-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-05-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-02-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-11-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 17,
#     'date': '2012-08-05',
#     'percentage': 0.015610651974288299,
#     'periodDays': 7,
#     'price': 10.87,
#     'revenue': 4619.75,
#     'reward': 25},
#    {'blocks': 8,
#     'date': '2012-04-29',
#     'percentage': 0.0081466395112016286,
#     'periodDays': 7,
#     'price': 4.9044,
#     'revenue': 980.88,
#     'reward': 25},
#    {'blocks': 0,
#     'date': '2012-01-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-05-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0}]}]

# %%
data = {'pools': blocksByPool,
        'dates': datesAndPrices,
        'sources': 
            [{ 'name': 'Organ of Corti',
               'data': 'Block mining data',
               'url': 'http://organofcorti.blogspot.com/',
               'file': False,
               'fileType': False },
             { 'name': 'Coindesk',
               'data': 'Bitcoin price data',
               'url': 'http://coindesk.com/api',
               'file': url,
               'fileType': 'json' }],
        'colophon': "Data is derived from claims made by miners, either on their websites or in coinbase signatures, and known addresses. Due to the anonymous nature of the Bitcoin network, mining (in the form of block solves) is only identifiable if declared, and even then is not verifiable. Notably, Slush's pool was the first in operation (in December 2010), but data for it only became available in January 2012. Data is weekly except for the three weeks when DeepBit, BTC Guild, and GHash.IO peaked, during which daily data is shown; thus, those jagged spans indicate higher-resolution data, not necessarily higher intrinsic volatility. Inferred network share percentages are subject to fluctuations due to luck; e.g., over a ten-minute period, there may be only one miner to successfully mine a block, but one should not infer an instantaneous network share of 100%. Furthermore, there is no guarantee that your sense perceptions correspond to an objective reality, or indeed that a world exists outside your head.",
        'credits': {'author': 'Toph Tucker'}
        }

with open('data.json', 'w') as outfile:
  json.dump(data, outfile)

# %%
datesums = blocksFrame.groupby('date').sum()
datesums
# Out:
#             blocks  percentage
# date
# 2011-02-27       6      0.3861
# 2011-03-06    1376    100.0000
# 2011-03-13    1212    100.0000
# 2011-03-20     853    100.0000
# 2011-03-27    1024    100.0000
# 2011-04-03    1187    100.0000
# 2011-04-10    1164    100.0000
# 2011-04-17    1162    100.0000
# 2011-04-24    1121    100.0000
# 2011-05-01    1285    100.0000
# 2011-05-08    1420    100.0000
# 2011-05-15    1450    100.0000
# 2011-05-22    1623    100.0000
# 2011-05-29    1762    100.0000
# 2011-06-05    1288    100.0000
# 2011-06-12    1493    100.0000
# 2011-06-19    1549    100.0000
# 2011-06-26    1569    100.0000
# 2011-07-03    1183    100.0000
# 2011-07-10    1076    100.0000
# 2011-07-17    1089    100.0000
# 2011-07-24    1080    100.0000
# 2011-07-31    1152    100.0000
# 2011-08-07    1042    100.0000
# 2011-08-14     958    100.0000
# 2011-08-21     971    100.0000
# 2011-08-28    1022    100.0000
# 2011-09-04     985    100.0000
# 2011-09-11     993    100.0000
# 2011-09-18     955    100.0000
# 2011-09-25     981    100.0000
# 2011-10-02     941    100.0000
# 2011-10-09     908    100.0000
# 2011-10-16     833    100.0000
# 2011-10-23     824    100.0000
# 2011-10-30     799    100.0000
# 2011-11-06     964    100.0000
# 2011-11-13     989    100.0000
# 2011-11-20     982    100.0000
# 2011-11-27     903    100.0000
# 2011-12-04    1021    100.0000
# 2011-12-11    1058    100.0000
# 2011-12-18     944    100.0000
# 2011-12-25    1021    100.0000
# 2012-01-01    1082    100.0000
# 2012-01-08    1114    100.0000
# 2012-01-15    1066    100.0000
# 2012-01-22    1058    100.0000
# 2012-01-29    1017    100.0000
# 2012-02-05    1104    100.0000
# 2012-02-12    1003    100.0000
# 2012-02-19    1028    100.0000
# 2012-02-26    1066    100.0000
# 2012-03-04    1041    100.0000
# 2012-03-11    1062    100.0000
# 2012-03-18    1041    100.0000
# 2012-03-25    1089    100.0000
# 2012-04-01    1079    100.0000
# 2012-04-08     910    100.0000
# 2012-04-15     973    100.0000
#                ...         ...
#
# [173 rows x 2 columns]

# %%
datesums.sort('percentage', ascending=1)
# Out:
#             blocks  percentage
# date
# 2011-02-27       6      0.3861
# 2014-04-27    1164    100.0000
# 2013-03-17    1165    100.0000
# 2012-11-04    1037    100.0000
# 2014-03-02    1217    100.0000
# 2012-11-11    1059    100.0000
# 2012-03-11    1062    100.0000
# 2012-04-22     987    100.0000
# 2013-10-06    1309    100.0000
# 2012-12-02    1081    100.0000
# 2011-12-04    1021    100.0000
# 2012-05-13    1076    100.0000
# 2012-06-03    1008    100.0000
# 2012-02-26    1066    100.0000
# 2013-02-10    1111    100.0000
# 2012-02-05    1104    100.0000
# 2011-12-11    1058    100.0000
# 2013-04-28    1149    100.0000
# 2011-12-25    1021    100.0000
# 2013-10-20    1523    100.0000
# 2011-07-17    1089    100.0000
# 2011-05-01    1285    100.0000
# 2012-07-15    1074    100.0000
# 2012-02-12    1003    100.0000
# 2013-02-24    1211    100.0000
# 2014-04-13    1082    100.0000
# 2012-06-10    1059    100.0000
# 2012-07-29    1117    100.0000
# 2012-08-05    1089    100.0000
# 2013-11-03    1330    100.0000
# 2012-12-23     897    100.0000
# 2012-11-18     983    100.0000
# 2013-12-01    1203    100.0000
# 2014-05-25    1183    100.0000
# 2013-12-22    1345    100.0000
# 2011-11-06     964    100.0000
# 2012-02-19    1028    100.0000
# 2013-08-18    1311    100.0000
# 2013-12-29    1185    100.0000
# 2013-05-05    1081    100.0000
# 2012-01-15    1066    100.0000
# 2011-03-20     853    100.0000
# 2013-06-16    1255    100.0000
# 2013-09-08    1302    100.0000
# 2012-10-28    1093    100.0000
# 2011-11-20     982    100.0000
# 2013-10-27    1508    100.0000
# 2011-06-19    1549    100.0000
# 2011-11-27     903    100.0000
# 2013-09-29    1348    100.0000
# 2011-10-16     833    100.0000
# 2013-09-15    1386    100.0000
# 2013-04-21    1103    100.0000
# 2011-09-11     993    100.0000
# 2011-04-24    1121    100.0000
# 2012-04-29     982    100.0000
# 2014-01-12    1353    100.0000
# 2011-06-05    1288    100.0000
# 2013-07-07    1185    100.0000
# 2011-05-08    1420    100.0000
#                ...         ...
#
# [173 rows x 2 columns]

# %%
datesums[date != '2011-02-27']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-357-6a230d914229> in <module>()
# ----> 1 datesums[date != '2011-02-27']
#
# /Users/traveler/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1656             return self._getitem_multilevel(key)
#    1657         else:
# -> 1658             return self._getitem_column(key)
#    1659
#    1660     def _getitem_column(self, key):
#
# /Users/traveler/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1663         # get column
#    1664         if self.columns.is_unique:
# -> 1665             return self._get_item_cache(key)
#    1666
#    1667         # duplicate columns & possible reduce dimensionaility
#
# /Users/traveler/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1003         res = cache.get(item)
#    1004         if res is None:
# -> 1005             values = self._data.get(item)
#    1006             res = self._box_item_values(item, values)
#    1007             cache[item] = res
#
# /Users/traveler/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2871                 return self.get_for_nan_indexer(indexer)
#    2872
# -> 2873             _, block = self._find_block(item)
#    2874             return block.get(item)
#    2875         else:
#
# /Users/traveler/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _find_block(self, item)
#    3183
#    3184     def _find_block(self, item):
# -> 3185         self._check_have(item)
#    3186         for i, block in enumerate(self.blocks):
#    3187             if item in block:
#
# /Users/traveler/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _check_have(self, item)
#    3190     def _check_have(self, item):
#    3191         if item not in self.items:
# -> 3192             raise KeyError('no item named %s' % com.pprint_thing(item))
#    3193
#    3194     def reindex_axis(self, new_axis, indexer=None, method=None, axis=0,
#
# KeyError: u'no item named True'
