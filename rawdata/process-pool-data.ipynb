# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
rawBlocksWeekly = pd.read_csv('weeklyBlockSolves.csv', parse_dates=['Date'])
rawBlocksDaily = pd.read_csv('dailyBlockSolves.csv', parse_dates=['Date'])

rawBlocksWeekly = rawBlocksWeekly.drop('Unnamed: 0', 1).rename(columns=
                                                           {'Date': 'date', 
                                                            'Pool': 'pool', 
                                                            'Number of Blocks': 'blocks', 
                                                            'Percentage of Blocks': 'percentage'})

rawBlocksDaily = rawBlocksDaily.drop('Unnamed: 0', 1).rename(columns=
                                                           {'Date': 'date', 
                                                            'Pool': 'pool', 
                                                            'Number of Blocks': 'blocks', 
                                                            'Percentage of Blocks': 'percentage'})

blocksFrame = rawBlocksWeekly

# (OVER)SPECIFIC LITTLE CLEANING ITEMS

# Remove dates where percentages total < 99%. 
# Last I checked there was only one such bad day: 2011-02-27.
# But hey, written for generality:
datesums = blocksFrame.groupby('date').sum()
badDays = datesums[datesums['percentage'] < 99].index.values
for badDay in badDays:
    blocksFrame = blocksFrame[blocksFrame['date'] != badDay]
# That leaves a gap so we reindex.
blocksFrame = blocksFrame.reset_index(drop=True)

# INTERPOLATION OF DAILY DATA ("ADAPTIVE RESAMPLING")
    
# Find three largest pools
topPools = blocksFrame.groupby('pool').max().sort('percentage', ascending=0)  #sort by max percentage
topPools = topPools.loc[topPools.index != "Unknown"]                          #filter out Unknown
topPools = topPools[:3]                                                       #take top 3

"""
Todo:
- [x] Find largest pools
- [x] For each pool...
- [x] Find day on which maxed out
- [ ] Find all earlier weeklies, 
- [ ]                            take greatest
- [ ] Find all later weeklies, 
- [ ]                            take least &
- [ ]                            remove from blocksFrame
- [ ] Append to blocksFrame all daily data from dates > former & dates <= latter
"""

for topPool in topPools.transpose().iteritems():
    poolName = topPool[0]
    
    # find date on which pool hit peak network share (percentage)
    poolMaxDate = rawBlocksDaily.iloc[rawBlocksDaily[rawBlocksDaily['pool'] == poolName]['percentage'].idxmax()]['date']
    
    # find lower bound for high-res region: find all earlier weeklies, and then take the greatest
    priorMines = rawBlocksWeekly[(rawBlocksWeekly['pool'] == poolName) & (rawBlocksWeekly['date'] < poolMaxDate)]
    priorMinesMaxId = priorMines['date'].idxmax()
    priorMinesMax = priorMines.loc[priorMinesMaxId].date
    
    # find upper bound for high-res region: find all later weeklies, and then take the least
    posteriorMines = rawBlocksWeekly[(rawBlocksWeekly['pool'] == poolName) & (rawBlocksWeekly['date'] >= poolMaxDate)]
    posteriorMinesMinId = posteriorMines['date'].idxmin()
    posteriorMinesMin = posteriorMines.loc[posteriorMinesMinId].date

    #todo: remove entries for posteriorMinesMin
    
    # append daily entries within bounding extent to main dataframe for processing and eventual export 
    blocksFrame = blocksFrame.append(rawBlocksDaily[(rawBlocksDaily['date'] > priorMinesMax) & (rawBlocksDaily['date'] <= posteriorMinesMin)])

# %%
import urllib2

# Get first and last days of pool block data (will be interval for prices)
dateMin = blocksFrame.iloc[blocksFrame['date'].idxmin()]['date'].strftime('%Y-%m-%d')
dateMax = blocksFrame.iloc[blocksFrame['date'].idxmax()]['date'].strftime('%Y-%m-%d')

# API only supports 2010-07-17 and later.
coindeskMin = '2010-07-17'
dateMin = dateMin if dateMin > coindeskMin else coindeskMin

# Fetching historical prices from Coindesk. API docs at http://www.coindesk.com/api/
url = 'http://api.coindesk.com/v1/bpi/historical/close.json?start='+dateMin+'&end='+dateMax
response = urllib2.urlopen(url)
pricesJSON = response.read()
prices = json.loads(pricesJSON)['bpi']

datesAndPrices = []
for x,y in prices.iteritems():
    datesAndPrices.append({'date': x, 'price': y})
    
datesAndPrices = sorted(datesAndPrices, key=lambda datesAndPrices: datesAndPrices['date'])

# %%
# Nest raw blocks 
pools = blocksFrame.groupby('pool').groups.keys()
dates = blocksFrame.groupby('date').groups.keys()

# Get aggregate statistics
poolMax = blocksFrame.groupby('pool').max()[['percentage']].rename(columns={'percentage':'maxPercentage'})
poolSum = blocksFrame.groupby('pool').sum()[['blocks']].rename(columns={'blocks':'sumBlocks'})
poolStats = poolMax.join(poolSum)

# Build an array of dictionaries fit for our eventual charting purposes
blocksByPool = []
for name, stats in poolStats.transpose().to_dict().iteritems():
    values = []
    
    for date in dates:
        
        # numpy date objects will be written to json as %Y-%m-%d
        dateString = pd.to_datetime(str(date)).strftime('%Y-%m-%d')
        
        results = blocksFrame[(blocksFrame['pool'] == name) & (blocksFrame['date'] == date)]
        if len(results) == 0:
            values.append(
                {'date': dateString, 
                 'percentage': 0, 
                 'blocks': 0, 
                 'price': 0,
                 'reward': 0,
                 'revenue': 0,
                 'periodDays': 7 })
        else:
            
            # Cf. https://bitcoinfoundation.org/2012/11/28/happy-halving-day/
            # Since this is just working off weekly data, revenue estimates for that week may be off!!!
            halvingday = np.datetime64('2012-11-28 15:24:38Z')
            reward = 50 if dates[9] < halvingday else 25
            
            # Fetch Bitcoin Coindesk Price Index (BPI) for date. Cf. www.coindesk.com/api/
            price = prices[dateString] if dateString in prices else 0
            
            values.append(
                {'date': dateString, 
                 'percentage': results[['percentage']].values[0][0]/100, 
                 'blocks': results[['blocks']].values[0][0],
                 'price': price,
                 'reward': reward,
                 'revenue': results[['blocks']].values[0][0] * price * reward,
                 'periodDays': 7 })
    
    blocksByPool.append(
        {'name': name, 
         'maxPercentage': stats['maxPercentage']/100, 
         'sumBlocks': stats['sumBlocks'],
         'values': values})

blocksByPool
# Out:
# [{'maxPercentage': 0.220735785953177,
#   'name': '50BTC.com',
#   'sumBlocks': 12159.0,
#   'values': [{'blocks': 0,
#     'date': '2011-03-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 219,
#     'date': '2013-07-28',
#     'percentage': 0.18961038961038998,
#     'periodDays': 7,
#     'price': 92.1,
#     'revenue': 1008494.9999999999,
#     'reward': 50},
#    {'blocks': 152,
#     'date': '2013-04-21',
#     'percentage': 0.13780598368086999,
#     'periodDays': 7,
#     'price': 119.2,
#     'revenue': 905920.00000000012,
#     'reward': 50},
#    {'blocks': 170,
#     'date': '2013-01-13',
#     'percentage': 0.17671517671517697,
#     'periodDays': 7,
#     'price': 14.116,
#     'revenue': 119985.99999999999,
#     'reward': 50},
#    {'blocks': 165,
#     'date': '2012-10-07',
#     'percentage': 0.16649848637739698,
#     'periodDays': 7,
#     'price': 11.8,
#     'revenue': 97350.000000000015,
#     'reward': 50},
#    {'blocks': 1,
#     'date': '2014-02-09',
#     'percentage': 0.00081566068515497589,
#     'periodDays': 7,
#     'price': 681.9371,
#     'revenue': 34096.854999999996,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 75,
#     'date': '2012-07-01',
#     'percentage': 0.074110671936758896,
#     'periodDays': 7,
#     'price': 6.629,
#     'revenue': 24858.749999999996,
#     'reward': 50},
#    {'blocks': 17,
#     'date': '2012-03-25',
#     'percentage': 0.015610651974288299,
#     'periodDays': 7,
#     'price': 4.55,
#     'revenue': 3867.4999999999995,
#     'reward': 50},
#    {'blocks': 5,
#     'date': '2012-01-29',
#     'percentage': 0.0049164208456243894,
#     'periodDays': 7,
#     'price': 5.3809,
#     'revenue': 1345.2249999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-12-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 8,
#     'date': '2014-04-13',
#     'percentage': 0.0073937153419593301,
#     'periodDays': 7,
#     'price': 414.9495,
#     'revenue': 165979.79999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-09-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 124,
#     'date': '2013-09-29',
#     'percentage': 0.09198813056379819,
#     'periodDays': 7,
#     'price': 125.1807,
#     'revenue': 776120.34000000008,
#     'reward': 50},
#    {'blocks': 29,
#     'date': '2013-05-02',
#     'percentage': 0.19205298013245004,
#     'periodDays': 7,
#     'price': 106.25,
#     'revenue': 154062.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 214,
#     'date': '2013-06-23',
#     'percentage': 0.19384057971014498,
#     'periodDays': 7,
#     'price': 107.9,
#     'revenue': 1154530.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 151,
#     'date': '2013-03-17',
#     'percentage': 0.12961373390557898,
#     'periodDays': 7,
#     'price': 47.4,
#     'revenue': 357870.0,
#     'reward': 50},
#    {'blocks': 181,
#     'date': '2012-12-09',
#     'percentage': 0.19504310344827602,
#     'periodDays': 7,
#     'price': 13.388,
#     'revenue': 121161.40000000001,
#     'reward': 50},
#    {'blocks': 152,
#     'date': '2012-09-02',
#     'percentage': 0.138433515482696,
#     'periodDays': 7,
#     'price': 10.2041,
#     'revenue': 77551.160000000003,
#     'reward': 50},
#    {'blocks': 30,
#     'date': '2012-05-27',
#     'percentage': 0.033444816053511697,
#     'periodDays': 7,
#     'price': 5.139,
#     'revenue': 7708.5000000000009,
#     'reward': 50},
#    {'blocks': 15,
#     'date': '2012-02-19',
#     'percentage': 0.014591439688716002,
#     'periodDays': 7,
#     'price': 4.3867,
#     'revenue': 3290.0250000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2014-03-09',
#     'percentage': 0.00090909090909090898,
#     'periodDays': 7,
#     'price': 633.1825,
#     'revenue': 31659.125,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 197,
#     'date': '2013-08-25',
#     'percentage': 0.14571005917159799,
#     'periodDays': 7,
#     'price': 111.795,
#     'revenue': 1101180.75,
#     'reward': 50},
#    {'blocks': 172,
#     'date': '2013-05-19',
#     'percentage': 0.15707762557077598,
#     'periodDays': 7,
#     'price': 122.5,
#     'revenue': 1053500.0,
#     'reward': 50},
#    {'blocks': 197,
#     'date': '2013-02-10',
#     'percentage': 0.177317731773177,
#     'periodDays': 7,
#     'price': 23.9698,
#     'revenue': 236102.52999999997,
#     'reward': 50},
#    {'blocks': 24,
#     'date': '2013-04-30',
#     'percentage': 0.13793103448275901,
#     'periodDays': 7,
#     'price': 139.2269,
#     'revenue': 167072.28,
#     'reward': 50},
#    {'blocks': 184,
#     'date': '2012-11-04',
#     'percentage': 0.17743490838958501,
#     'periodDays': 7,
#     'price': 10.8001,
#     'revenue': 99360.920000000013,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-12-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 74,
#     'date': '2012-07-29',
#     'percentage': 0.066248880931065401,
#     'periodDays': 7,
#     'price': 8.7103,
#     'revenue': 32228.109999999997,
#     'reward': 50},
#    {'blocks': 19,
#     'date': '2012-04-22',
#     'percentage': 0.0192502532928065,
#     'periodDays': 7,
#     'price': 5.2035,
#     'revenue': 4943.3249999999998,
#     'reward': 50},
#    {'blocks': 2,
#     'date': '2012-01-15',
#     'percentage': 0.0018761726078799197,
#     'periodDays': 7,
#     'price': 7.0018,
#     'revenue': 700.18000000000006,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-05-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-02-02',
#     'percentage': 0.0016934801016088099,
#     'periodDays': 7,
#     'price': 854.375,
#     'revenue': 85437.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-07-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 15,
#     'date': '2013-10-27',
#     'percentage': 0.0099469496021220086,
#     'periodDays': 7,
#     'price': 185.6888,
#     'revenue': 139266.60000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-03-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 244,
#     'date': '2013-07-21',
#     'percentage': 0.20299500831946801,
#     'periodDays': 7,
#     'price': 85.4725,
#     'revenue': 1042764.5,
#     'reward': 50},
#    {'blocks': 155,
#     'date': '2013-04-14',
#     'percentage': 0.13069139966273199,
#     'periodDays': 7,
#     'price': 90,
#     'revenue': 697500,
#     'reward': 50},
#    {'blocks': 208,
#     'date': '2013-01-06',
#     'percentage': 0.18995433789954302,
#     'periodDays': 7,
#     'price': 13.454,
#     'revenue': 139921.60000000001,
#     'reward': 50},
#    {'blocks': 167,
#     'date': '2012-09-30',
#     'percentage': 0.15506035283194097,
#     'periodDays': 7,
#     'price': 12.4,
#     'revenue': 103540.00000000001,
#     'reward': 50},
#    {'blocks': 73,
#     'date': '2012-06-24',
#     'percentage': 0.068288119738073,
#     'periodDays': 7,
#     'price': 6.35,
#     'revenue': 23177.499999999996,
#     'reward': 50},
#    {'blocks': 4,
#     'date': '2014-04-06',
#     'percentage': 0.0031796502384737703,
#     'periodDays': 7,
#     'price': 460.7028,
#     'revenue': 92140.559999999998,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-09-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 103,
#     'date': '2013-09-22',
#     'percentage': 0.081875993640699501,
#     'periodDays': 7,
#     'price': 122.651,
#     'revenue': 631652.65000000002,
#     'reward': 50},
#    {'blocks': 240,
#     'date': '2013-06-16',
#     'percentage': 0.19123505976095603,
#     'periodDays': 7,
#     'price': 99.9,
#     'revenue': 1198800.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-10-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 153,
#     'date': '2013-03-10',
#     'percentage': 0.13624220837043599,
#     'periodDays': 7,
#     'price': 46,
#     'revenue': 351900,
#     'reward': 50},
#    {'blocks': 214,
#     'date': '2012-12-02',
#     'percentage': 0.19796484736355199,
#     'periodDays': 7,
#     'price': 12.5,
#     'revenue': 133750.0,
#     'reward': 50},
#    {'blocks': 139,
#     'date': '2012-08-26',
#     'percentage': 0.122359154929577,
#     'periodDays': 7,
#     'price': 10.61,
#     'revenue': 73739.5,
#     'reward': 50},
#    {'blocks': 26,
#     'date': '2012-05-20',
#     'percentage': 0.027659574468085101,
#     'periodDays': 7,
#     'price': 5.09,
#     'revenue': 6617.0,
#     'reward': 50},
#    {'blocks': 11,
#     'date': '2012-02-12',
#     'percentage': 0.0109670987038883,
#     'periodDays': 7,
#     'price': 5.5147,
#     'revenue': 3033.085,
#     'reward': 50},
#    {'blocks': 2,
#     'date': '2014-06-08',
#     'percentage': 0.0017050298380221699,
#     'periodDays': 7,
#     'price': 653.6402,
#     'revenue': 65364.020000000004,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-11-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-03-02',
#     'percentage': 0.0016433853738701699,
#     'periodDays': 7,
#     'price': 560.3045,
#     'revenue': 56030.449999999997,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-07-31',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2013-11-24',
#     'percentage': 0.00086281276962899098,
#     'periodDays': 7,
#     'price': 751.377,
#     'revenue': 37568.849999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-04-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 224,
#     'date': '2013-08-18',
#     'percentage': 0.170861937452326,
#     'periodDays': 7,
#     'price': 98.845,
#     'revenue': 1107064.0,
#     'reward': 50},
#    {'blocks': 197,
#     'date': '2013-05-12',
#     'percentage': 0.16666666666666699,
#     'periodDays': 7,
#     'price': 114.82,
#     'revenue': 1130976.9999999998,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 202,
#     'date': '2013-02-03',
#     'percentage': 0.18330308529945602,
#     'periodDays': 7,
#     'price': 20.59,
#     'revenue': 207959.0,
#     'reward': 50},
#    {'blocks': 169,
#     'date': '2012-10-28',
#     'percentage': 0.15462031107044802,
#     'periodDays': 7,
#     'price': 10.7,
#     'revenue': 90415.0,
#     'reward': 50},
#    {'blocks': 21,
#     'date': '2013-05-03',
#     'percentage': 0.15671641791044799,
#     'periodDays': 7,
#     'price': 98.1,
#     'revenue': 103005.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 57,
#     'date': '2012-07-22',
#     'percentage': 0.054755043227665695,
#     'periodDays': 7,
#     'price': 8.4096,
#     'revenue': 23967.360000000001,
#     'reward': 50},
#    {'blocks': 16,
#     'date': '2012-04-15',
#     'percentage': 0.016443987667009198,
#     'periodDays': 7,
#     'price': 4.9689,
#     'revenue': 3975.1199999999999,
#     'reward': 50},
#    {'blocks': 2,
#     'date': '2012-01-08',
#     'percentage': 0.0017953321364452398,
#     'periodDays': 7,
#     'price': 7.1136,
#     'revenue': 711.36000000000001,
#     'reward': 50},
#    {'blocks': 4,
#     'date': '2014-05-04',
#     'percentage': 0.0035842293906810001,
#     'periodDays': 7,
#     'price': 434.0643,
#     'revenue': 86812.860000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-10-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-01-26',
#     'percentage': 0.0015961691939345602,
#     'periodDays': 7,
#     'price': 880.1523,
#     'revenue': 88015.229999999996,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-06-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 76,
#     'date': '2013-10-20',
#     'percentage': 0.049901510177281699,
#     'periodDays': 7,
#     'price': 163.0632,
#     'revenue': 619640.16000000003,
#     'reward': 50},
#    {'blocks': 225,
#     'date': '2013-07-14',
#     'percentage': 0.18101367658889803,
#     'periodDays': 7,
#     'price': 90.3713,
#     'revenue': 1016677.125,
#     'reward': 50},
#    {'blocks': 20,
#     'date': '2013-04-29',
#     'percentage': 0.11299435028248599,
#     'periodDays': 7,
#     'price': 143.9999,
#     'revenue': 143999.89999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 111,
#     'date': '2013-04-07',
#     'percentage': 0.09265442404006681,
#     'periodDays': 7,
#     'price': 162.301,
#     'revenue': 900770.55000000005,
#     'reward': 50},
#    {'blocks': 192,
#     'date': '2012-12-30',
#     'percentage': 0.191808191808192,
#     'periodDays': 7,
#     'price': 13.45,
#     'revenue': 129119.99999999999,
#     'reward': 50},
#    {'blocks': 158,
#     'date': '2012-09-23',
#     'percentage': 0.141704035874439,
#     'periodDays': 7,
#     'price': 12.1933,
#     'revenue': 96327.070000000007,
#     'reward': 50},
#    {'blocks': 67,
#     'date': '2012-06-17',
#     'percentage': 0.061865189289011996,
#     'periodDays': 7,
#     'price': 6.1638,
#     'revenue': 20648.73,
#     'reward': 50},
#    {'blocks': 14,
#     'date': '2013-05-01',
#     'percentage': 0.093959731543624192,
#     'periodDays': 7,
#     'price': 116.38,
#     'revenue': 81466.0,
#     'reward': 50},
#    {'blocks': 21,
#     'date': '2012-03-11',
#     'percentage': 0.019774011299434999,
#     'periodDays': 7,
#     'price': 4.91,
#     'revenue': 5155.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-12-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 5,
#     'date': '2014-03-30',
#     'percentage': 0.0040322580645161298,
#     'periodDays': 7,
#     'price': 461.8695,
#     'revenue': 115467.375,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 122,
#     'date': '2013-09-15',
#     'percentage': 0.088023088023088003,
#     'periodDays': 7,
#     'price': 124.5783,
#     'revenue': 759927.63,
#     'reward': 50},
#    {'blocks': 245,
#     'date': '2013-06-09',
#     'percentage': 0.18393393393393395,
#     'periodDays': 7,
#     'price': 100.4374,
#     'revenue': 1230358.1499999999,
#     'reward': 50},
#    {'blocks': 173,
#     'date': '2013-03-03',
#     'percentage': 0.146114864864865,
#     'periodDays': 7,
#     'price': 34.5,
#     'revenue': 298425.0,
#     'reward': 50},
#    {'blocks': 195,
#     'date': '2012-11-25',
#     'percentage': 0.185891325071497,
#     'periodDays': 7,
#     'price': 12.4821,
#     'revenue': 121700.47500000001,
#     'reward': 50},
#    {'blocks': 86,
#     'date': '2012-08-19',
#     'percentage': 0.079189686924493602,
#     'periodDays': 7,
#     'price': 8,
#     'revenue': 34400,
#     'reward': 50},
#    {'blocks': 24,
#     'date': '2012-05-13',
#     'percentage': 0.022304832713754597,
#     'periodDays': 7,
#     'price': 4.93,
#     'revenue': 5916.0,
#     'reward': 50},
#    {'blocks': 11,
#     'date': '2012-02-05',
#     'percentage': 0.0099637681159420299,
#     'periodDays': 7,
#     'price': 5.6888,
#     'revenue': 3128.8400000000001,
#     'reward': 50},
#    {'blocks': 79,
#     'date': '2012-08-12',
#     'percentage': 0.071622846781505003,
#     'periodDays': 7,
#     'price': 11.624,
#     'revenue': 45914.800000000003,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 3,
#     'date': '2014-02-23',
#     'percentage': 0.0024549918166939396,
#     'periodDays': 7,
#     'price': 604.5823,
#     'revenue': 90687.345000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-07-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2013-11-17',
#     'percentage': 0.0015748031496063001,
#     'periodDays': 7,
#     'price': 476.295,
#     'revenue': 47629.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-04-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 220,
#     'date': '2013-08-11',
#     'percentage': 0.16248153618906902,
#     'periodDays': 7,
#     'price': 94.1625,
#     'revenue': 1035787.5,
#     'reward': 50},
#    {'blocks': 164,
#     'date': '2013-05-05',
#     'percentage': 0.151711378353376,
#     'periodDays': 7,
#     'price': 115.98,
#     'revenue': 951036.0,
#     'reward': 50},
#    {'blocks': 188,
#     'date': '2013-01-27',
#     'percentage': 0.19164118246687104,
#     'periodDays': 7,
#     'price': 17.8182,
#     'revenue': 167491.08000000002,
#     'reward': 50},
#    {'blocks': 204,
#     'date': '2012-10-21',
#     'percentage': 0.19558964525407499,
#     'periodDays': 7,
#     'price': 11.6311,
#     'revenue': 118637.22,
#     'reward': 50},
#    {'blocks': 46,
#     'date': '2012-07-15',
#     'percentage': 0.042830540037243903,
#     'periodDays': 7,
#     'price': 7.621,
#     'revenue': 17528.300000000003,
#     'reward': 50},
#    {'blocks': 13,
#     'date': '2012-04-08',
#     'percentage': 0.014285714285714299,
#     'periodDays': 7,
#     'price': 4.7925,
#     'revenue': 3115.1250000000005,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-01-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-04-27',
#     'percentage': 0.0017182130584192405,
#     'periodDays': 7,
#     'price': 429.6537,
#     'revenue': 42965.370000000003,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-09-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2014-01-19',
#     'percentage': 0.00081103000811029999,
#     'periodDays': 7,
#     'price': 878.6807,
#     'revenue': 43934.035000000003,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-06-19',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 61,
#     'date': '2013-10-13',
#     'percentage': 0.047955974842767306,
#     'periodDays': 7,
#     'price': 130.4155,
#     'revenue': 397767.27500000002,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 195,
#     'date': '2013-07-07',
#     'percentage': 0.16455696202531597,
#     'periodDays': 7,
#     'price': 72.5053,
#     'revenue': 706926.67500000005,
#     'reward': 50},
#    {'blocks': 126,
#     'date': '2013-03-31',
#     'percentage': 0.110043668122271,
#     'periodDays': 7,
#     'price': 93.03,
#     'revenue': 586089.0,
#     'reward': 50},
#    {'blocks': 198,
#     'date': '2012-12-23',
#     'percentage': 0.220735785953177,
#     'periodDays': 7,
#     'price': 13.312,
#     'revenue': 131788.79999999999,
#     'reward': 50},
#    {'blocks': 150,
#     'date': '2012-09-16',
#     'percentage': 0.143540669856459,
#     'periodDays': 7,
#     'price': 11.87,
#     'revenue': 89024.999999999985,
#     'reward': 50},
#    {'blocks': 183,
#     'date': '2012-10-14',
#     'percentage': 0.17784256559766798,
#     'periodDays': 7,
#     'price': 11.7389,
#     'revenue': 107410.935,
#     'reward': 50},
#    {'blocks': 50,
#     'date': '2012-06-10',
#     'percentage': 0.0472143531633617,
#     'periodDays': 7,
#     'price': 5.4683,
#     'revenue': 13670.750000000002,
#     'reward': 50},
#    {'blocks': 14,
#     'date': '2012-03-04',
#     'percentage': 0.013448607108549499,
#     'periodDays': 7,
#     'price': 4.82,
#     'revenue': 3374.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-04-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 6,
#     'date': '2014-03-23',
#     'percentage': 0.0051238257899231402,
#     'periodDays': 7,
#     'price': 561.3534,
#     'revenue': 168406.01999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-21',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 1,
#     'date': '2013-12-15',
#     'percentage': 0.00079176563737133805,
#     'periodDays': 7,
#     'price': 879.4692,
#     'revenue': 43973.459999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-05-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 153,
#     'date': '2013-09-08',
#     'percentage': 0.11751152073732701,
#     'periodDays': 7,
#     'price': 116.595,
#     'revenue': 891951.75,
#     'reward': 50},
#    {'blocks': 218,
#     'date': '2013-06-02',
#     'percentage': 0.17694805194805202,
#     'periodDays': 7,
#     'price': 122.5,
#     'revenue': 1335250.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 225,
#     'date': '2013-02-24',
#     'percentage': 0.18579686209744001,
#     'periodDays': 7,
#     'price': 29.89,
#     'revenue': 336262.5,
#     'reward': 50},
#    {'blocks': 168,
#     'date': '2012-11-18',
#     'percentage': 0.17090539165818899,
#     'periodDays': 7,
#     'price': 11.6515,
#     'revenue': 97872.600000000006,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 3,
#     'date': '2014-05-25',
#     'percentage': 0.0025359256128486894,
#     'periodDays': 7,
#     'price': 570.095,
#     'revenue': 85514.25,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 3,
#     'date': '2014-02-16',
#     'percentage': 0.0025167785234899306,
#     'periodDays': 7,
#     'price': 610.6525,
#     'revenue': 91597.875,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-07-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 239,
#     'date': '2013-08-04',
#     'percentage': 0.187893081761006,
#     'periodDays': 7,
#     'price': 96.6,
#     'revenue': 1154370.0,
#     'reward': 50},
#    {'blocks': 194,
#     'date': '2013-04-28',
#     'percentage': 0.16884247171453398,
#     'periodDays': 7,
#     'price': 134.4444,
#     'revenue': 1304110.6799999999,
#     'reward': 50},
#    {'blocks': 33,
#     'date': '2012-05-06',
#     'percentage': 0.028374892519346499,
#     'periodDays': 7,
#     'price': 5.0499,
#     'revenue': 8332.3350000000009,
#     'reward': 50},
#    {'blocks': 182,
#     'date': '2013-01-20',
#     'percentage': 0.19612068965517199,
#     'periodDays': 7,
#     'price': 15.7,
#     'revenue': 142870.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 40,
#     'date': '2012-07-08',
#     'percentage': 0.037418147801683802,
#     'periodDays': 7,
#     'price': 6.799,
#     'revenue': 13598.000000000002,
#     'reward': 50},
#    {'blocks': 17,
#     'date': '2012-04-01',
#     'percentage': 0.015755329008341101,
#     'periodDays': 7,
#     'price': 4.827,
#     'revenue': 4102.9499999999998,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-12-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 2,
#     'date': '2014-04-20',
#     'percentage': 0.0016542597187758502,
#     'periodDays': 7,
#     'price': 497.3177,
#     'revenue': 49731.769999999997,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-09-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 104,
#     'date': '2013-10-06',
#     'percentage': 0.079449961802902994,
#     'periodDays': 7,
#     'price': 121.6828,
#     'revenue': 632750.56000000006,
#     'reward': 50},
#    {'blocks': 193,
#     'date': '2013-06-30',
#     'percentage': 0.16768027801911398,
#     'periodDays': 7,
#     'price': 97.51,
#     'revenue': 940971.5,
#     'reward': 50},
#    {'blocks': 160,
#     'date': '2013-03-24',
#     'percentage': 0.110803324099723,
#     'periodDays': 7,
#     'price': 71.5,
#     'revenue': 572000.0,
#     'reward': 50},
#    {'blocks': 172,
#     'date': '2012-12-16',
#     'percentage': 0.191964285714286,
#     'periodDays': 7,
#     'price': 13.3,
#     'revenue': 114380.0,
#     'reward': 50},
#    {'blocks': 183,
#     'date': '2012-09-09',
#     'percentage': 0.16080843585237301,
#     'periodDays': 7,
#     'price': 11.02,
#     'revenue': 100833.0,
#     'reward': 50},
#    {'blocks': 39,
#     'date': '2012-06-03',
#     'percentage': 0.038690476190476206,
#     'periodDays': 7,
#     'price': 5.2051,
#     'revenue': 10149.945,
#     'reward': 50},
#    {'blocks': 28,
#     'date': '2013-05-04',
#     'percentage': 0.20437956204379604,
#     'periodDays': 7,
#     'price': 112.9,
#     'revenue': 158060.0,
#     'reward': 50},
#    {'blocks': 13,
#     'date': '2012-02-26',
#     'percentage': 0.012195121951219499,
#     'periodDays': 7,
#     'price': 4.922,
#     'revenue': 3199.2999999999997,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-11-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 5,
#     'date': '2014-03-16',
#     'percentage': 0.0043936731107205602,
#     'periodDays': 7,
#     'price': 630.7167,
#     'revenue': 157679.17499999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 21,
#     'date': '2012-03-18',
#     'percentage': 0.020172910662824197,
#     'periodDays': 7,
#     'price': 5.2794,
#     'revenue': 5543.3699999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-05-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 157,
#     'date': '2013-09-01',
#     'percentage': 0.12256049960968002,
#     'periodDays': 7,
#     'price': 128.2597,
#     'revenue': 1006838.645,
#     'reward': 50},
#    {'blocks': 194,
#     'date': '2013-05-26',
#     'percentage': 0.176363636363636,
#     'periodDays': 7,
#     'price': 133.5,
#     'revenue': 1294950.0,
#     'reward': 50},
#    {'blocks': 208,
#     'date': '2013-02-17',
#     'percentage': 0.18102697998259398,
#     'periodDays': 7,
#     'price': 26.8146,
#     'revenue': 278871.83999999997,
#     'reward': 50},
#    {'blocks': 182,
#     'date': '2012-11-11',
#     'percentage': 0.171860245514636,
#     'periodDays': 7,
#     'price': 10.8687,
#     'revenue': 98905.170000000013,
#     'reward': 50},
#    {'blocks': 81,
#     'date': '2012-08-05',
#     'percentage': 0.0743801652892562,
#     'periodDays': 7,
#     'price': 10.87,
#     'revenue': 44023.499999999993,
#     'reward': 50},
#    {'blocks': 22,
#     'date': '2012-04-29',
#     'percentage': 0.022403258655804503,
#     'periodDays': 7,
#     'price': 4.9044,
#     'revenue': 5394.8400000000001,
#     'reward': 50},
#    {'blocks': 6,
#     'date': '2012-01-22',
#     'percentage': 0.0056710775047259,
#     'periodDays': 7,
#     'price': 6.3097,
#     'revenue': 1892.9100000000001,
#     'reward': 50},
#    {'blocks': 4,
#     'date': '2014-05-18',
#     'percentage': 0.0034692107545533394,
#     'periodDays': 7,
#     'price': 444.809,
#     'revenue': 88961.800000000003,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-10-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0}]},
#  {'maxPercentage': 0.125114155251142,
#   'name': 'BitMinter',
#   'sumBlocks': 5849.0,
#   'values': [{'blocks': 0,
#     'date': '2011-03-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 78,
#     'date': '2013-11-03',
#     'percentage': 0.058646616541353398,
#     'periodDays': 7,
#     'price': 207.6335,
#     'revenue': 809770.65000000002,
#     'reward': 50},
#    {'blocks': 1,
#     'date': '2011-07-10',
#     'percentage': 0.00092936802973977702,
#     'periodDays': 7,
#     'price': 14.9,
#     'revenue': 745.0,
#     'reward': 50},
#    {'blocks': 32,
#     'date': '2013-07-28',
#     'percentage': 0.027705627705627695,
#     'periodDays': 7,
#     'price': 92.1,
#     'revenue': 147360.0,
#     'reward': 50},
#    {'blocks': 91,
#     'date': '2013-04-21',
#     'percentage': 0.0825022665457842,
#     'periodDays': 7,
#     'price': 119.2,
#     'revenue': 542360.0,
#     'reward': 50},
#    {'blocks': 61,
#     'date': '2013-01-13',
#     'percentage': 0.063409563409563399,
#     'periodDays': 7,
#     'price': 14.116,
#     'revenue': 43053.800000000003,
#     'reward': 50},
#    {'blocks': 70,
#     'date': '2012-10-07',
#     'percentage': 0.070635721493440995,
#     'periodDays': 7,
#     'price': 11.8,
#     'revenue': 41300.0,
#     'reward': 50},
#    {'blocks': 29,
#     'date': '2014-02-09',
#     'percentage': 0.023654159869494304,
#     'periodDays': 7,
#     'price': 681.9371,
#     'revenue': 988808.79499999993,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 15,
#     'date': '2012-07-01',
#     'percentage': 0.014822134387351799,
#     'periodDays': 7,
#     'price': 6.629,
#     'revenue': 4971.7499999999991,
#     'reward': 50},
#    {'blocks': 11,
#     'date': '2012-03-25',
#     'percentage': 0.0101010101010101,
#     'periodDays': 7,
#     'price': 4.55,
#     'revenue': 2502.5,
#     'reward': 50},
#    {'blocks': 10,
#     'date': '2012-01-29',
#     'percentage': 0.0098328416912487702,
#     'periodDays': 7,
#     'price': 5.3809,
#     'revenue': 2690.4499999999998,
#     'reward': 50},
#    {'blocks': 8,
#     'date': '2011-12-18',
#     'percentage': 0.0084745762711864389,
#     'periodDays': 7,
#     'price': 3.193,
#     'revenue': 1277.2,
#     'reward': 50},
#    {'blocks': 15,
#     'date': '2014-04-13',
#     'percentage': 0.013863216266173796,
#     'periodDays': 7,
#     'price': 414.9495,
#     'revenue': 311212.125,
#     'reward': 50},
#    {'blocks': 1,
#     'date': '2011-09-11',
#     'percentage': 0.0010070493454179302,
#     'periodDays': 7,
#     'price': 5.8644,
#     'revenue': 293.21999999999997,
#     'reward': 50},
#    {'blocks': 28,
#     'date': '2014-01-05',
#     'percentage': 0.024013722126929701,
#     'periodDays': 7,
#     'price': 940.0972,
#     'revenue': 1316136.0800000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-06-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 38,
#     'date': '2013-09-29',
#     'percentage': 0.028189910979228502,
#     'periodDays': 7,
#     'price': 125.1807,
#     'revenue': 237843.33000000002,
#     'reward': 50},
#    {'blocks': 13,
#     'date': '2013-05-02',
#     'percentage': 0.086092715231788103,
#     'periodDays': 7,
#     'price': 106.25,
#     'revenue': 69062.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 28,
#     'date': '2013-06-23',
#     'percentage': 0.025362318840579701,
#     'periodDays': 7,
#     'price': 107.9,
#     'revenue': 151060.0,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 56,
#     'date': '2013-03-17',
#     'percentage': 0.048068669527896998,
#     'periodDays': 7,
#     'price': 47.4,
#     'revenue': 132720.0,
#     'reward': 50},
#    {'blocks': 82,
#     'date': '2012-12-09',
#     'percentage': 0.08836206896551721,
#     'periodDays': 7,
#     'price': 13.388,
#     'revenue': 54890.800000000003,
#     'reward': 50},
#    {'blocks': 49,
#     'date': '2012-09-02',
#     'percentage': 0.044626593806921695,
#     'periodDays': 7,
#     'price': 10.2041,
#     'revenue': 25000.044999999998,
#     'reward': 50},
#    {'blocks': 12,
#     'date': '2012-05-27',
#     'percentage': 0.013377926421404699,
#     'periodDays': 7,
#     'price': 5.139,
#     'revenue': 3083.4000000000005,
#     'reward': 50},
#    {'blocks': 8,
#     'date': '2012-02-19',
#     'percentage': 0.0077821011673151795,
#     'periodDays': 7,
#     'price': 4.3867,
#     'revenue': 1754.6800000000001,
#     'reward': 50},
#    {'blocks': 17,
#     'date': '2014-06-15',
#     'percentage': 0.015205724508050099,
#     'periodDays': 7,
#     'price': 591.9718,
#     'revenue': 503176.02999999997,
#     'reward': 50},
#    {'blocks': 7,
#     'date': '2011-11-13',
#     'percentage': 0.0070778564206269001,
#     'periodDays': 7,
#     'price': 2.9969,
#     'revenue': 1048.915,
#     'reward': 50},
#    {'blocks': 15,
#     'date': '2014-03-09',
#     'percentage': 0.013636363636363603,
#     'periodDays': 7,
#     'price': 633.1825,
#     'revenue': 474886.87499999994,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-08-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 59,
#     'date': '2013-12-01',
#     'percentage': 0.049044056525353305,
#     'periodDays': 7,
#     'price': 946.9237,
#     'revenue': 2793424.9150000005,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-05-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 48,
#     'date': '2013-08-25',
#     'percentage': 0.035502958579881699,
#     'periodDays': 7,
#     'price': 111.795,
#     'revenue': 268308.0,
#     'reward': 50},
#    {'blocks': 137,
#     'date': '2013-05-19',
#     'percentage': 0.125114155251142,
#     'periodDays': 7,
#     'price': 122.5,
#     'revenue': 839125.0,
#     'reward': 50},
#    {'blocks': 73,
#     'date': '2013-02-10',
#     'percentage': 0.065706570657065699,
#     'periodDays': 7,
#     'price': 23.9698,
#     'revenue': 87489.770000000004,
#     'reward': 50},
#    {'blocks': 14,
#     'date': '2013-04-30',
#     'percentage': 0.0804597701149425,
#     'periodDays': 7,
#     'price': 139.2269,
#     'revenue': 97458.830000000002,
#     'reward': 50},
#    {'blocks': 86,
#     'date': '2012-11-04',
#     'percentage': 0.082931533269045302,
#     'periodDays': 7,
#     'price': 10.8001,
#     'revenue': 46440.43,
#     'reward': 50},
#    {'blocks': 3,
#     'date': '2011-12-11',
#     'percentage': 0.00283553875236295,
#     'periodDays': 7,
#     'price': 3.2511,
#     'revenue': 487.66499999999996,
#     'reward': 50},
#    {'blocks': 36,
#     'date': '2012-07-29',
#     'percentage': 0.032229185317815601,
#     'periodDays': 7,
#     'price': 8.7103,
#     'revenue': 15678.540000000001,
#     'reward': 50},
#    {'blocks': 6,
#     'date': '2012-04-22',
#     'percentage': 0.0060790273556231011,
#     'periodDays': 7,
#     'price': 5.2035,
#     'revenue': 1561.05,
#     'reward': 50},
#    {'blocks': 9,
#     'date': '2012-01-15',
#     'percentage': 0.0084427767354596592,
#     'periodDays': 7,
#     'price': 7.0018,
#     'revenue': 3150.8100000000004,
#     'reward': 50},
#    {'blocks': 17,
#     'date': '2014-05-11',
#     'percentage': 0.014847161572052401,
#     'periodDays': 7,
#     'price': 436.542,
#     'revenue': 371060.70000000001,
#     'reward': 50},
#    {'blocks': 5,
#     'date': '2011-10-09',
#     'percentage': 0.0055066079295154205,
#     'periodDays': 7,
#     'price': 4.1029,
#     'revenue': 1025.7249999999999,
#     'reward': 50},
#    {'blocks': 22,
#     'date': '2014-02-02',
#     'percentage': 0.018628281117696897,
#     'periodDays': 7,
#     'price': 854.375,
#     'revenue': 939812.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-07-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 81,
#     'date': '2013-10-27',
#     'percentage': 0.053713527851458893,
#     'periodDays': 7,
#     'price': 185.6888,
#     'revenue': 752039.64000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-03-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 34,
#     'date': '2013-07-21',
#     'percentage': 0.028286189683860197,
#     'periodDays': 7,
#     'price': 85.4725,
#     'revenue': 145303.25,
#     'reward': 50},
#    {'blocks': 94,
#     'date': '2013-04-14',
#     'percentage': 0.079258010118043801,
#     'periodDays': 7,
#     'price': 90,
#     'revenue': 423000,
#     'reward': 50},
#    {'blocks': 50,
#     'date': '2013-01-06',
#     'percentage': 0.045662100456620995,
#     'periodDays': 7,
#     'price': 13.454,
#     'revenue': 33635.0,
#     'reward': 50},
#    {'blocks': 70,
#     'date': '2012-09-30',
#     'percentage': 0.064995357474466109,
#     'periodDays': 7,
#     'price': 12.4,
#     'revenue': 43400.0,
#     'reward': 50},
#    {'blocks': 20,
#     'date': '2012-06-24',
#     'percentage': 0.018709073900841901,
#     'periodDays': 7,
#     'price': 6.35,
#     'revenue': 6350.0,
#     'reward': 50},
#    {'blocks': 9,
#     'date': '2014-04-06',
#     'percentage': 0.0071542130365659807,
#     'periodDays': 7,
#     'price': 460.7028,
#     'revenue': 207316.26000000001,
#     'reward': 50},
#    {'blocks': 5,
#     'date': '2011-09-04',
#     'percentage': 0.0050761421319796994,
#     'periodDays': 7,
#     'price': 8.178,
#     'revenue': 2044.5,
#     'reward': 50},
#    {'blocks': 63,
#     'date': '2013-12-29',
#     'percentage': 0.053164556962025308,
#     'periodDays': 7,
#     'price': 745.0712,
#     'revenue': 2346974.2799999998,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-05-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 33,
#     'date': '2013-09-22',
#     'percentage': 0.026232114467408599,
#     'periodDays': 7,
#     'price': 122.651,
#     'revenue': 202374.14999999999,
#     'reward': 50},
#    {'blocks': 74,
#     'date': '2013-06-16',
#     'percentage': 0.058964143426294802,
#     'periodDays': 7,
#     'price': 99.9,
#     'revenue': 369630.0,
#     'reward': 50},
#    {'blocks': 12,
#     'date': '2011-10-23',
#     'percentage': 0.014563106796116498,
#     'periodDays': 7,
#     'price': 3.17,
#     'revenue': 1902.0,
#     'reward': 50},
#    {'blocks': 34,
#     'date': '2013-03-10',
#     'percentage': 0.030276046304541403,
#     'periodDays': 7,
#     'price': 46,
#     'revenue': 78200,
#     'reward': 50},
#    {'blocks': 89,
#     'date': '2012-12-02',
#     'percentage': 0.082331174838112892,
#     'periodDays': 7,
#     'price': 12.5,
#     'revenue': 55625.0,
#     'reward': 50},
#    {'blocks': 41,
#     'date': '2012-08-26',
#     'percentage': 0.0360915492957746,
#     'periodDays': 7,
#     'price': 10.61,
#     'revenue': 21750.5,
#     'reward': 50},
#    {'blocks': 15,
#     'date': '2012-05-20',
#     'percentage': 0.015957446808510602,
#     'periodDays': 7,
#     'price': 5.09,
#     'revenue': 3817.4999999999995,
#     'reward': 50},
#    {'blocks': 8,
#     'date': '2012-02-12',
#     'percentage': 0.0079760717846460594,
#     'periodDays': 7,
#     'price': 5.5147,
#     'revenue': 2205.8800000000001,
#     'reward': 50},
#    {'blocks': 16,
#     'date': '2014-06-08',
#     'percentage': 0.013640238704177299,
#     'periodDays': 7,
#     'price': 653.6402,
#     'revenue': 522912.16000000003,
#     'reward': 50},
#    {'blocks': 5,
#     'date': '2011-11-06',
#     'percentage': 0.0051867219917012394,
#     'periodDays': 7,
#     'price': 2.9596,
#     'revenue': 739.89999999999998,
#     'reward': 50},
#    {'blocks': 21,
#     'date': '2014-03-02',
#     'percentage': 0.0172555464256368,
#     'periodDays': 7,
#     'price': 560.3045,
#     'revenue': 588319.72499999998,
#     'reward': 50},
#    {'blocks': 1,
#     'date': '2011-07-31',
#     'percentage': 0.00086805555555555594,
#     'periodDays': 7,
#     'price': 13.35,
#     'revenue': 667.5,
#     'reward': 50},
#    {'blocks': 68,
#     'date': '2013-11-24',
#     'percentage': 0.058671268334771397,
#     'periodDays': 7,
#     'price': 751.377,
#     'revenue': 2554681.7999999998,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-04-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 44,
#     'date': '2013-08-18',
#     'percentage': 0.033562166285278396,
#     'periodDays': 7,
#     'price': 98.845,
#     'revenue': 217459.0,
#     'reward': 50},
#    {'blocks': 143,
#     'date': '2013-05-12',
#     'percentage': 0.12098138747884901,
#     'periodDays': 7,
#     'price': 114.82,
#     'revenue': 820962.99999999988,
#     'reward': 50},
#    {'blocks': 1,
#     'date': '2014-06-09',
#     'percentage': 0.0073529411764705907,
#     'periodDays': 7,
#     'price': 645.341,
#     'revenue': 32267.049999999999,
#     'reward': 50},
#    {'blocks': 68,
#     'date': '2013-02-03',
#     'percentage': 0.061705989110707807,
#     'periodDays': 7,
#     'price': 20.59,
#     'revenue': 70006.0,
#     'reward': 50},
#    {'blocks': 92,
#     'date': '2012-10-28',
#     'percentage': 0.084172003659652314,
#     'periodDays': 7,
#     'price': 10.7,
#     'revenue': 49220.0,
#     'reward': 50},
#    {'blocks': 10,
#     'date': '2013-05-03',
#     'percentage': 0.074626865671641798,
#     'periodDays': 7,
#     'price': 98.1,
#     'revenue': 49050.0,
#     'reward': 50},
#    {'blocks': 2,
#     'date': '2014-06-11',
#     'percentage': 0.0119760479041916,
#     'periodDays': 7,
#     'price': 627.9098,
#     'revenue': 62790.980000000003,
#     'reward': 50},
#    {'blocks': 25,
#     'date': '2012-07-22',
#     'percentage': 0.024015369836695499,
#     'periodDays': 7,
#     'price': 8.4096,
#     'revenue': 10511.999999999998,
#     'reward': 50},
#    {'blocks': 8,
#     'date': '2012-04-15',
#     'percentage': 0.0082219938335046198,
#     'periodDays': 7,
#     'price': 4.9689,
#     'revenue': 1987.5599999999999,
#     'reward': 50},
#    {'blocks': 14,
#     'date': '2012-01-08',
#     'percentage': 0.012567324955116699,
#     'periodDays': 7,
#     'price': 7.1136,
#     'revenue': 4979.5200000000004,
#     'reward': 50},
#    {'blocks': 21,
#     'date': '2014-05-04',
#     'percentage': 0.018817204301075301,
#     'periodDays': 7,
#     'price': 434.0643,
#     'revenue': 455767.51500000001,
#     'reward': 50},
#    {'blocks': 1,
#     'date': '2011-10-02',
#     'percentage': 0.0010626992561105198,
#     'periodDays': 7,
#     'price': 5.027,
#     'revenue': 251.34999999999999,
#     'reward': 50},
#    {'blocks': 21,
#     'date': '2014-01-26',
#     'percentage': 0.0167597765363128,
#     'periodDays': 7,
#     'price': 880.1523,
#     'revenue': 924159.91500000004,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2011-06-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 85,
#     'date': '2013-10-20',
#     'percentage': 0.0558108995403808,
#     'periodDays': 7,
#     'price': 163.0632,
#     'revenue': 693018.59999999998,
#     'reward': 50},
#    {'blocks': 38,
#     'date': '2013-07-14',
#     'percentage': 0.030571198712791604,
#     'periodDays': 7,
#     'price': 90.3713,
#     'revenue': 171705.47,
#     'reward': 50},
#    {'blocks': 9,
#     'date': '2013-04-29',
#     'percentage': 0.050847457627118703,
#     'periodDays': 7,
#     'price': 143.9999,
#     'revenue': 64799.955000000002,
#     'reward': 50},
#    {'blocks': 3,
#     'date': '2014-06-14',
#     'percentage': 0.0184049079754601,
#     'periodDays': 7,
#     'price': 571.6902,
#     'revenue': 85753.529999999999,
#     'reward': 50},
#    {'blocks': 59,
#     'date': '2013-04-07',
#     'percentage': 0.049248747913188604,
#     'periodDays': 7,
#     'price': 162.301,
#     'revenue': 478787.95000000001,
#     'reward': 50},
#    {'blocks': 54,
#     'date': '2012-12-30',
#     'percentage': 0.053946053946053896,
#     'periodDays': 7,
#     'price': 13.45,
#     'revenue': 36315.0,
#     'reward': 50},
#    {'blocks': 67,
#     'date': '2012-09-23',
#     'percentage': 0.060089686098654699,
#     'periodDays': 7,
#     'price': 12.1933,
#     'revenue': 40847.555,
#     'reward': 50},
#    {'blocks': 20,
#     'date': '2012-06-17',
#     'percentage': 0.018467220683287201,
#     'periodDays': 7,
#     'price': 6.1638,
#     'revenue': 6163.8000000000002,
#     'reward': 50},
#    {'blocks': 6,
#     'date': '2013-05-01',
#     'percentage': 0.040268456375838903,
#     'periodDays': 7,
#     'price': 116.38,
#     'revenue': 34914.0,
#     'reward': 50},
#    {'blocks': 4,
#     'date': '2012-03-11',
#     'percentage': 0.003766478342749529,
#     'periodDays': 7,
#     'price': 4.91,
#     'revenue': 982.0,
#     'reward': 50},
#    {'blocks': 5,
#     'date': '2011-12-04',
#     'percentage': 0.0048971596474045101,
#     'periodDays': 7,
#     'price': 2.8281,
#     'revenue': 707.02499999999998,
#     'reward': 50},
#    {'blocks': 15,
#     'date': '2014-03-30',
#     'percentage': 0.012096774193548401,
#     'periodDays': 7,
#     'price': 461.8695,
#     'revenue': 346402.125,
#     'reward': 50},
#    {'blocks': 4,
#     'date': '2011-08-28',
#     'percentage': 0.0039138943248532305,
#     'periodDays': 7,
#     'price': 9.0701,
#     'revenue': 1814.02,
#     'reward': 50},
#    {'blocks': 62,
#     'date': '2013-12-22',
# ...
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-05-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-06-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 18,
#     'date': '2012-07-22',
#     'percentage': 0.017291066282420803,
#     'periodDays': 7,
#     'price': 8.4096,
#     'revenue': 7568.6399999999994,
#     'reward': 50},
#    {'blocks': 13,
#     'date': '2012-04-15',
#     'percentage': 0.013360739979445001,
#     'periodDays': 7,
#     'price': 4.9689,
#     'revenue': 3229.7849999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-01-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-05-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-03-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-10-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-07-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-04-29',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-06-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-04-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-12-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-09-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 17,
#     'date': '2012-06-17',
#     'percentage': 0.015697137580794097,
#     'periodDays': 7,
#     'price': 6.1638,
#     'revenue': 5239.2299999999996,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2013-05-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-03-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-12-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-09-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-06-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-03-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-11-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 12,
#     'date': '2012-08-19',
#     'percentage': 0.011049723756906099,
#     'periodDays': 7,
#     'price': 8,
#     'revenue': 4800,
#     'reward': 50},
#    {'blocks': 35,
#     'date': '2012-05-13',
#     'percentage': 0.032527881040892201,
#     'periodDays': 7,
#     'price': 4.93,
#     'revenue': 8627.5,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-02-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 16,
#     'date': '2012-08-12',
#     'percentage': 0.014505893019039,
#     'periodDays': 7,
#     'price': 11.624,
#     'revenue': 9299.2000000000007,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2014-06-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-02-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-08-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-05-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-01-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-10-21',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 18,
#     'date': '2012-07-15',
#     'percentage': 0.0167597765363128,
#     'periodDays': 7,
#     'price': 7.621,
#     'revenue': 6858.8999999999996,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-04-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-01-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-04-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-09-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-19',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-19',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-10-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-05',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-07-07',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-03-31',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-12-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-09-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-10-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 22,
#     'date': '2012-06-10',
#     'percentage': 0.0207743153918791,
#     'periodDays': 7,
#     'price': 5.4683,
#     'revenue': 6015.1300000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-03-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-27',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-23',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-21',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-15',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-09-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-06-02',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-06-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-02-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-11-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-06-13',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-05-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-03',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-02-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-07-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-11-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-04-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-08-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-04-28',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 18,
#     'date': '2012-05-06',
#     'percentage': 0.0154772141014617,
#     'periodDays': 7,
#     'price': 5.0499,
#     'revenue': 4544.9099999999999,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2013-01-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-06-10',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 13,
#     'date': '2012-07-08',
#     'percentage': 0.0121608980355472,
#     'periodDays': 7,
#     'price': 6.799,
#     'revenue': 4419.3500000000004,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-04-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-12-25',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-04-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-09-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-01-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-06-12',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-10-06',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-06-30',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-03-24',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-12-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-09-09',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 51,
#     'date': '2012-06-03',
#     'percentage': 0.050595238095238096,
#     'periodDays': 7,
#     'price': 5.2051,
#     'revenue': 13273.005000000001,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2013-05-04',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-02-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-11-20',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-03-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-08-14',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-12-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-03-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-05-08',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-09-01',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-05-26',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2013-02-17',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2012-11-11',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 17,
#     'date': '2012-08-05',
#     'percentage': 0.015610651974288299,
#     'periodDays': 7,
#     'price': 10.87,
#     'revenue': 9239.5,
#     'reward': 50},
#    {'blocks': 8,
#     'date': '2012-04-29',
#     'percentage': 0.0081466395112016286,
#     'periodDays': 7,
#     'price': 4.9044,
#     'revenue': 1961.76,
#     'reward': 50},
#    {'blocks': 0,
#     'date': '2012-01-22',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2014-05-18',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0},
#    {'blocks': 0,
#     'date': '2011-10-16',
#     'percentage': 0,
#     'periodDays': 7,
#     'price': 0,
#     'revenue': 0,
#     'reward': 0}]}]

# %%
data = {'pools': blocksByPool,
        'dates': datesAndPrices,
        'sources': 
            [{ 'name': 'Organ of Corti',
               'data': 'Block mining data',
               'url': 'http://organofcorti.blogspot.com/',
               'file': False,
               'fileType': False },
             { 'name': 'Coindesk',
               'data': 'Bitcoin price data',
               'url': 'http://coindesk.com/api',
               'file': url,
               'fileType': 'json' }],
        'colophon': "Data is derived from claims made by miners, either on their websites or in coinbase signatures, and known addresses. Due to the anonymous nature of the Bitcoin network, mining (in the form of block solves) is only identifiable if declared, and even then is not verifiable. Notably, Slush's pool was the first in operation (in December 2010), but data for it only became available in January 2012. Data is weekly except for the three weeks when DeepBit, BTC Guild, and GHash.IO peaked, during which daily data is shown; thus, those jagged spans indicate higher-resolution data, not necessarily higher intrinsic volatility. Inferred network share percentages are subject to fluctuations due to luck; e.g., over a ten-minute period, there may be only one miner to successfully mine a block, but one should not infer an instantaneous network share of 100%. Furthermore, there is no guarantee that your sense perceptions correspond to an objective reality, or indeed that a world exists outside your head.",
        'credits': {'author': 'Toph Tucker'}
        }

with open('data.json', 'w') as outfile:
  json.dump(data, outfile)
